# %%
import numpy as np
import pandas as pd
import random
import json
from opensearchpy import OpenSearch
import os
OPENSEARCH_HOST = os.getenv("OPENSEARCH_HOST", "localhost")
OPENSEARCH_PORT = os.getenv("OPENSEARCH_PORT", 9200)

# %%
def interleave(listA, listB, k):
    ids = []
    teams = []
    rank = 1
    idx_a = 0
    idx_b = 0
    len_a = len(listA)
    len_b = len(listB)

    while rank <= k:
        a_val = listA[idx_a]['_id'] if idx_a < len_a else None
        b_val = listB[idx_b]['_id'] if idx_b < len_b else None
        if not (a_val and b_val):
            # lists are done
            return zip(ids, teams)
        if not a_val:
            # take the rest of listB
            for hit in listB[idx_b:k]['_id']:
                if hit not in ids:
                    ids.append(hit)
                    teams.append('TeamB')
            return zip(ids, teams)
        if not b_val:
            # take the rest of listA
            for hit in listA['_id']:
                if hit not in ids:
                    ids.append(hit)
                    teams.append('TeamB')
            return zip(ids, teams)
        a_first = idx_a < idx_b or idx_a == idx_b and random.randint(0,1)
        if a_first:
            if a_val not in ids:
                ids.append(a_val)
                teams.append('TeamA')
                rank += 1
            idx_a += 1
        else:
            if b_val not in ids:
                ids.append(b_val)
                teams.append('TeamB')
                rank += 1
            idx_b += 1       
    return list(zip(ids, teams))


def get_list(listA, listB, k):
    A = listA['hits']['hits']
    B = listB['hits']['hits']
    interleaving = interleave(A, B, k)
    return interleaving

def get_search_config(client, name):
    search_configs_index = '.plugins-search-relevance-search-config'
    conf = client.search( body = {
      "query": {
        "match": {"name": name}
      },
      "size": 1
    }, index=search_configs_index)
    return conf['hits']['hits'][0]['_source'] if len(conf['hits']['hits']) else {}

def populate_query(query, config, size=10, source=["title", "description", "asin"]):
    query = query.replace('"', '\\"')
    body = config['queryBody'].replace("%SearchText%", query)
    return {
        "query": json.loads(body),
        "size": size,
        "_source": source
    }

def run_AB(client, query, configA, configB, size=10):
    confA = get_search_config(client, configA)
    confB = get_search_config(client, configB)
    qA = populate_query(query, confA, size=size)
    qB = populate_query(query, confB, size=size)
    #TODO: extract the endpoint value from the search config, rather than using the client here
    resA = client.search(body=qA)
    resB = client.search(body=qB)
    result = get_list(resA, resB, 10)
    return result

def get_events(client, id, query, event_type=None):
    if event_type:
        evq = {
          "query": {
            "bool": {
             "must": [   
                 {"match": {"event_attributes.object.object_id": id}},
                 {"match": {"user_query": query}},
                 {"match": {"action_name": event_type}}
             ]
            }
          },
          "size": 1000
        }
    else:
        evq = {
          "query": {
            "bool": {
             "must": [   
                 {"match": {"event_attributes.object.object_id": id}},
                 {"match": {"user_query": query}}
             ]
            }
          },
          "size": 1000
        }
    results = client.search(body=evq, index='ubi_events')
    return results

def get_clicks(client, id, query):
    results = get_events(client, id, query, 'click')
    return results

def count_clicks(client, id, query):
    results = get_clicks(client, id, query)
    return results['hits']['total']['value']

# %%
# Create the client with SSL/TLS and hostname verification disabled.
client = OpenSearch(
    hosts = [{'host': OPENSEARCH_HOST, 'port': OPENSEARCH_PORT}],
    http_compress = True, # enables gzip compression for request bodies
    use_ssl = False,
    verify_certs = False,
    ssl_assert_hostname = False,
    ssl_show_warn = False
)

# %%
ubi_queries = client.search(body={'query': {'match_all': {}}, "size":10000-31, "from": 31}, index='ubi_queries')
ubi_user_queries = [x['_source']['user_query'] for x in ubi_queries['hits']['hits']]
ubi_user_queries
# Out:
# ['vibrator',
#  'weighted blanket',
#  'apple watch',
#  'air fryer',
#  'surge protector power strip',
#  'firestick',
#  'gift not included batteries',
#  'futon frames full size without mattress',
#  'tv',
#  'portable charger',
#  'earbuds',
#  'boots',
#  'dresser',
#  'bite not collar',
#  'yoga mat',
#  'water bottles',
#  'futon frames full size without mattress',
#  'hawaiian shirts for women',
#  'tv',
#  'chromebook',
#  'minecraft',
#  'portable charger',
#  'tv',
#  'apple watch',
#  'tv',
#  'nintendo switch games',
#  'bluetooth headphones',
#  'poleras largas mujer',
#  'gloves',
#  'christmas lights',
#  'pokemon',
#  'rc drone without camera',
#  'gifts for women',
#  'rc drone without camera',
#  'shoes',
#  'floor lamps for living room',
#  'food',
#  'yeti',
#  '3d printer',
#  'toilet paper',
#  'ipod touch',
#  'ipad',
#  'basketball',
#  'printer',
#  'echo dot',
#  'ps4',
#  'sewing machine',
#  'prime movies',
#  'ugg slippers women',
#  'paper towels',
#  'airpods',
#  'barbie dolls',
#  'iphone 11 case',
#  '30 inch ceiling fan without light',
#  'shoes for women',
#  'womens tops',
#  'laptop',
#  'yeezy',
#  'firestick',
#  'dildo',
#  'music',
#  'wireless headphones',
#  'yeti',
#  'ps4',
#  'bluetooth headphones',
#  'yeti',
#  'ipad',
#  'rc drone without camera',
#  'air fryer',
#  'ugg slippers women',
#  'mouse pad',
#  'laundry basket',
#  'nintendo switch',
#  'yoga mat',
#  'paper towels',
#  'ban idiots not guns',
#  'iphone',
#  'free',
#  'macbook pro',
#  'dog harness',
#  'iphone x case',
#  'laptops',
#  'futon frames full size without mattress',
#  'adidas shoes men',
#  'prime movies',
#  'poleras largas mujer',
#  'apple headphones',
#  'shoes for men',
#  'airpods',
#  'womens clogs open back',
#  'phone',
#  'kayak',
#  'vacuum cleaner',
#  'rugs',
#  'apple earbuds',
#  'hydro flask',
#  'headphones',
#  'shoes',
#  'vibrator',
#  'boots',
#  'gaming chair',
#  'firestick',
#  'blender',
#  'iphone 11',
#  'wireless earbuds',
#  'iphone 11',
#  'apple earphones',
#  'rings',
#  'hp laptop',
#  'gloves',
#  'mouse pad',
#  'womens shoes',
#  'laptop',
#  'shoes for women',
#  'echo dot',
#  'hoverboard',
#  'dog food',
#  'mattress',
#  'face mask',
#  'boots',
#  'compression socks women',
#  'wireless earbuds',
#  'room decor',
#  'gaming chair',
#  'shoes',
#  'airpods 2',
#  'ipad',
#  'rugs',
#  'camera',
#  'mouse',
#  'baby wipes',
#  'nike',
#  'mouse pad',
#  'cap toe brown shoes',
#  'portable charger',
#  'treadmill',
#  'earrings',
#  'ipad',
#  'patio furniture',
#  'airpods 2',
#  'sunglasses',
#  'treadmill',
#  'barbie dolls',
#  'free',
#  'iphone xr',
#  'hand soap',
#  'portable charger',
#  'mini fridge',
#  'lightning cable',
#  'gaming chair',
#  'mini fridge',
#  'tv',
#  'laptop',
#  'cricut maker',
#  'apple headphones',
#  'patio furniture',
#  'apple watch',
#  'blender',
#  'boots',
#  'apple watch series 3',
#  'ugg slippers women',
#  'tv',
#  'k cups',
#  'shoes',
#  'earbuds',
#  'food',
#  'tablet',
#  'iphone',
#  'dresses for women party wedding',
#  'watches for women',
#  'gift boxes without lids',
#  'gucci luggage',
#  'full size daybed without trundle',
#  'full length mirror',
#  'bmw 6 series body kit',
#  'air mattress',
#  'storage cubes',
#  'black toilet seat',
#  'ruzell aftershave',
#  'pout pout fish toy',
#  'buccaneer dog gear',
#  'fungus on toenails',
#  'bathroom scale without bluetooth',
#  'dulcolax liquid laxative',
#  'camping without beer is just sitting in the woods',
#  'wall space heater',
#  'to do list white board for wall',
#  'short sleeved tops for women casual',
#  'little mermaid',
#  'eaton type ch 50 amp breaker',
#  'candy',
#  'sofa recliner for living room',
#  'cats make me happy, you not so much',
#  'lol dolls',
#  'towing accessories',
#  'badges without borders',
#  'rep fitness power rack',
#  'kids vitamins without gelatin',
#  'work smarter not harder',
#  'zone mouthguard',
#  '1/2gallon water bottle without straw',
#  'ipad',
#  'multiprocess welder',
#  'my body is a garden not a graveyard shirt',
#  'dont tread on me stickers',
#  'wooden new york cut out',
#  'sewing machine',
#  'joggers without pockets',
#  'adidas sneakers men',
#  'liner for litter box 21x15',
#  'mud pie valentines day',
#  'tall makeup chair',
#  'bass amp headphones',
#  'the boys',
#  'panang red curry paste',
#  '2 station 4 color screen printing',
#  'smart watch',
#  '01 ford ranger headlights not smoke lens',
#  'fire hd 10',
#  'big brown mirror',
#  'black label ketones',
#  'sram battery charger',
#  'coffee maker not keurig',
#  'do not bend sticker',
#  '$2 pop tube not a pack',
#  'kwanza candle holder',
#  'surely not everyone',
#  'fire pit',
#  'shaker bottle',
#  'dulcolax liquid laxative',
#  'valet umbrella',
#  'showerheads with handheld shower high pressure',
#  'tabernacle model kit',
#  'flag pole',
#  'pario table',
#  'floral wallpaper stick and peel',
#  'gun',
#  'redken blue shampoo and conditioner',
#  'ladles plastic',
#  'sprinkles are for cupcakes not toilet seats',
#  'water flasks bottles steel',
#  'ladder',
#  'cousin shirts for kids',
#  'womens witch costumes plus size',
#  'german toothbrush',
#  'hi mirror mini premium x',
#  'large non sticking frying pan with lid',
#  'the amazon nightgown dress',
#  'gildan tee shirts women',
#  'stick n poke tattoo kit',
#  'lounge pants womens',
#  'porch lock box for packages',
#  'coffee grinder',
#  'childrens place clothing for girls',
#  '10x7 patio gazebo with or without screen',
#  'sex dolls',
#  '5xl carhartt shirts for men big and tall',
#  'cycling shoes without cleats',
#  'adobe incense burner',
#  '10mm oil burner bent without connector',
#  'grow long marc anthony',
#  'kaweco sketch up pencil',
#  'cotton high cut underwear for women',
#  'airpods',
#  'huge white board for wall',
#  'hot af slim jim',
#  'mens belt without buckle leather',
#  'desk lamp',
#  '10 inch fan',
#  'magnetic brown eyeliner',
#  'sweatshirt without hood for men',
#  'blue and brown wall decor',
#  'antiseptic wipes individually wrapped',
#  'pre k classroom decorations',
#  'vinpositine',
#  'back off i have a sister and im not afraid to use her',
#  'home office chair without wheels',
#  'lincoln plasma cutter',
#  'best seller',
#  'air nike jordan 1',
#  'poly vi sol multivitamin infant without iron',
#  'natural bathroom sink cleaner',
#  'yogurt and fruit container',
#  '.22 pellets not lead',
#  'bingo game set with cards',
#  'cauliflower rice frozen organic',
#  'cliff bars chocolate chip value pack',
#  'lox earring backs',
#  'toe pads for heels',
#  'baby dolls',
#  'the north is not enough t',
#  'wallets for men',
#  'carro control remoto',
#  'healthy snacks without nuts',
#  'transformers',
#  'coffee maker',
#  'daily planner without dates',
#  'toilet paper',
#  'big and tall t shirts',
#  'priority mail shipping labels',
#  'almay deodorant',
#  'laser etching machine',
#  'you can’t tell me what to do you are not my granddaughter',
#  'vibrators',
#  'usb',
#  'can opener',
#  'good feet store for women',
#  'all in one computer',
#  'eboys stuff',
#  'corner desks for sale',
#  'cactus outdoor decor',
#  'mtb frame protector',
#  'unlocked cell phones',
#  'wine',
#  'bum genius one size cloth diapers',
#  'kaufman bath mats',
#  'halloween wallets for women',
#  'spring flags for outdoors 28 x 40 double sided',
#  'vegie steamer',
#  'adidas gym bag for women',
#  'white silk pillowcase standard',
#  'black funeral dress',
#  'red paddle board',
#  'travel bottles',
#  'mct oil without lauric acid',
#  'left facing sectional sofa',
#  'birds make me happy you not so much',
#  'titan distributors inc.',
#  'do not walk on grass sign with stake',
#  '16 x 32 frame',
#  'dustbin without lid',
#  'tennis twist machine',
#  'fimibuke',
#  'retro green throw pillows',
#  'magnetic eyelashes',
#  'plus body chains for women sexy',
#  'agility training kit',
#  'seiko sportura watches for men',
#  'triple push pop',
#  'lol dance dance dance doll omg',
#  'its in my dna cuba',
#  'tear stain remover for french bulldog',
#  'lighting without electricity',
#  'sunflower wreaths for front door outside',
#  'mole repeller without poison',
#  'camelbak backpack',
#  'watch the game not your phone tshirt',
#  'rgb lights for room',
#  'cerave gentle cleanser',
#  'bodum french presses',
#  'padded toilet seat round',
#  '11 piece knife set without block',
#  'h10 yellow led',
#  'scotch expressions masking tape',
#  'a5 travelers notebook',
#  'rigid wet saw',
#  'gucci belts for women',
#  'lube without glycerin',
#  'dutch processes cocoa powder',
#  'snkk45',
#  'h11 rgb led headlight bulb',
#  'sports bras for women',
#  'im not throwing away my shot',
#  'chinaware',
#  'bows',
#  'mega construx masters of the universe',
#  'yoga swing without handles',
#  'i want a warm jacket with a hood and that is waterproof and black or dark coloured like navy',
#  'piano accessories',
#  'red and blue christmas ornaments',
#  'medicine measuring cups',
#  'hair waves without heat',
#  'expo white board cleaner',
#  'pure dhea 25mg',
#  'gtx titan',
#  '8x10 toploader',
#  'jeris hair tonic without oil',
#  'beauti sleep elixir',
#  '4xl jackets for men big and tall',
#  'large faux 2.5 ct diamond ring',
#  'open tow booties for women',
#  'candy pink and blue',
#  '4k tv',
#  'flonase nasal spray generic',
#  '10’ tow rope for jetski without hooks',
#  'magnetic brown eyeliner',
#  'xs sexy 2 piece outfits for women',
#  'izotope rx7',
#  '44 inch ceiling fan without light',
#  'iu perfume',
#  'digger toys for boys',
#  'empire hair human hair',
#  'twin xl comforter sets for college girls',
#  'strip lights music 16.4ft',
#  'thin tweezers',
#  'gaming keyboard',
#  'nyquil without acetaminophen',
#  '1 crib mattress this is not sold with the crib',
#  'juicy toddler girl',
#  'herman miller x logitech g embody gaming chair',
#  'rooftop cargo bag without roof rack',
#  'protein powder',
#  'pants skinny for women',
#  'wawa coffee',
#  'flourite substrate black',
#  'compression socks',
#  "women's rash guard shirts",
#  'lobby chairs without arms',
#  'xbox one controller',
#  'pure supplements magnesium',
#  'body mirror',
#  'shoe rack',
#  'pit sectional',
#  'utah state university',
#  'dr brown pacifiers 0-6 months',
#  'raw peanuts without skin',
#  'patio furniture with storage underneath',
#  'white gold thin hoop earrings',
#  'shower head without restrictor',
#  'pressing mat for quilting',
#  'artificial tears without preservatives',
#  'mycologist shirt',
#  'swimsuits women high waisted two piece',
#  'clean and perfect cleaner',
#  'gunfam action base',
#  'couch cover',
#  'murphy bed',
#  'safavieh lighting collection table lamp',
#  'dog pads extra large 100 count',
#  '300 win mag muzzle brake',
#  'kona coffee whole bean',
#  'black mustard seeds',
#  'low profileadjustable bed frame',
#  'japan deep frying pan',
#  '32 d bras for women',
#  'water shoes',
#  'wig',
#  'oxford button down shirts for men short sleeve',
#  'mamma bear diapers',
#  'solar srting lights',
#  'lip scrub',
#  'wireless earbuds',
#  'two yr old girls toys',
#  'educational toys for 4 year olds',
#  '75 carat diamond rings curved',
#  'ricoma embroidery machine',
#  '100%silk pillowcase 2 pack without zipper',
#  'empowerplus advanced formula',
#  'k mini plus',
#  'fifth wheel to gooseneck adapter12”',
#  'kitchen toys set for kids',
#  '11 piece knife set without block',
#  'rebel without a cause poster',
#  'boys pants slim fit',
#  'salt gun',
#  'shower curtain liner',
#  'leap frog magic adventures globes for kids interactive',
#  'wife beatters mens 4xl big and tall',
#  '1 in curtain rod black without brackets',
#  '1lb dumbbells',
#  'dream pairs flats for women',
#  'water bottles',
#  'natures way essential oils',
#  'laundry carts baskets with wheels',
#  'woods decorations for home',
#  'hat mask combo',
#  'bath scrungies',
#  'queen comforter',
#  'yoga tanks tops',
#  'hitachi magic wand rechargeable',
#  'mccormick black peppercorn grinder, 2.5 oz',
#  'boys toys 5 years old most popular',
#  'no chicken soup',
#  'sushi rolls not gender roles',
#  'jet jointer',
#  '0-3 month swimsuit boy',
#  'plant plate to catch water',
#  'longeray sexy for women',
#  'thorne basic nutrients v without iron and iodine',
#  '13 gallon trash bin',
#  'sexy ninja costumes for women',
#  'back off i have a sister and im not afraid to use her',
#  'spread love not germs sticker',
#  'water trampoline for lake',
#  'hand cleaner without pumice',
#  'biomemd probiotic and prebiotic for women',
#  'hublot womens watch',
#  'bookends decorative unique',
#  'taylor bbt big baby taylor acoustic guitar',
#  'mexican train dominoes accessories',
#  'pete rose autographed baseball',
#  'common milkweed seeds',
#  'blackfly sunglasses men',
#  'lomg sleeve black crop tops',
#  'massage table',
#  'food pouch holder no squeeze',
#  'massage gun',
#  'cbd oil',
#  '0.9% sodium chloride without preservatives usp',
#  'fur real toys',
#  'dogs make me happy you not so much',
#  'yeti tall thin can cooler',
#  'side console for aluminum boat',
#  'lip balm',
#  'floral high low dresses for women',
#  'front closure strapless bras',
#  '10 kt gold chain',
#  'farmhouse industrial lighting',
#  'mens diamond watches',
#  'slime without borax',
#  'reading glasses without arms',
#  'spirit essences for cats by jackson galaxy',
#  'sheer 108 inches long',
#  'foco miami dolphins',
#  'st teresa of avila',
#  'baby bottles',
#  'bifocal sunglasses for women',
#  'energy monitoring',
#  'j necklace',
#  'snap together pavers',
#  '60 lashes',
#  'coasters funny saying',
#  'mom shorts high waisted',
#  'kinetico k5 drinking water station',
#  'qsc amplifier',
#  'can cooler slim can',
#  'casual clothes for women',
#  'atainless steel straws',
#  'framed album covers',
#  "women's sweatshirts without hoods",
#  'jordan love jersey green bay packers',
#  'shoes',
#  "'may not be perfect' canvas",
#  'vitamin c serum without hyaluronic acid',
#  'humidifiers',
#  'nutrients to age without senility',
#  'sage fitted sheet queen',
#  'black lol dolls for girls',
#  'overnight travel cosmetic cases',
#  'black fan without light',
#  'do not give into the war within shirt',
#  'primary composition notebook without picture space',
#  '06 tailgate without clearance lights',
#  'satco lightbulb',
#  'i may not have a phd',
#  's10',
#  'treadmill',
#  'ross simons tennis necklace',
#  'mens 7.5 wide black loafers',
#  'fanny pack',
#  'curly hair products without alcohol',
#  'pocket yoga pants',
#  'aaa aa batteries combo',
#  'apple watch series 2 42mm band',
#  'mr heater propane golf cart heater',
#  '90 degree leggings without pockets',
#  '14k rose gold earrings',
#  'chicco car seat',
#  'plus size tanks for women loose fit',
#  '22 gold chain for men',
#  'no children swimming without adult supervision sign',
#  'hot pink one piece swimsuits for women',
#  '1 1/4” sink drain without overflow',
#  'pool',
#  'vmax charizard',
#  'furry ottoman',
#  'chik-fil-a sauce',
#  'raven crossbows',
#  'hacker mask without blush',
#  'large accent chairs',
#  'overalls for women',
#  'pea not cups',
#  'gucci inspire watches',
#  'womens multivitamin without iron',
#  'roses chocolates cadbury',
#  'hakone yosegi',
#  'dragon maid figures',
#  'taysers',
#  'wicked ball for dogs',
#  'hanging pictures without nails',
#  'candy canes',
#  'organic multivitamin without biotin',
#  '100 foot led cuttable light without plug',
#  'fart machine with remote',
#  'bras sexy for women',
#  'wall dividers for rooms cheap',
#  'anime makes me happy you not so much',
#  'hanging paintings without nails',
#  'gold tennis bracelet set for women',
#  'mace weapon medieval',
#  'elkay water dispenser',
#  "i'm not procrastinating",
#  'rio badge printer badges',
#  'nurse bags for work supplies',
#  'barnies santas white christmas coffee',
#  'winter gloves',
#  'wllet',
#  '501 levis jeans for men',
#  'silicon rings male and female',
#  'mezcal and tequila infusion set',
#  'cheddar cheese',
#  'key ring',
#  'baby girl clothes daddys little girl',
#  'pet botanics mini training rewards dog treats',
#  'bottle shelf for bar',
#  'washable ziplock bags dishwasher safe',
#  'leupold scout scope',
#  'pictorico pro ultra premium ohp transparency film',
#  'vsco stickers',
#  'forgrip',
#  'halo',
#  'legging shorts high waisted plus size',
#  'police academy graduation',
#  'apple watch series 3',
#  'globels fidget toys',
#  'pink white and gold balloons',
#  'organic juice not from concentrate',
#  'best dog toys to keep them busy',
#  'womens athletic shorts',
#  '.sock for henicape can not felldown',
#  'sticker by number books',
#  '2 t tutu',
#  'zombie ghost mask',
#  'habitant pea soup',
#  'bar stools',
#  '1 inch wooden beads for crafts without holes',
#  'eva nyc mane magic 10-in-1 primer',
#  'books for babies newborn to one year',
#  'kitten collar without a bell',
#  'mega construx masters of the universe',
#  'vacuum',
#  'clear sneaker box',
#  'water wipes',
#  'fart machine with remote',
#  'miter saw',
#  'no fog glasses spray',
#  'light switch without wiring',
#  '#6 fishing hook without barb',
#  'love is not cancelled',
#  'shape wear panty',
#  'fish cookbook',
#  'ulysse nardin royal blue “mystery” tourbillon watch',
#  'men top long john',
#  'hair color without harsh chemicals',
#  '1 1/4 mini metal rustic barn star without hole for the',
#  'small picture frames',
#  '0.0 sticker not today',
#  'baby pink throw blanket',
#  '102 vinyl tablecloth',
#  'girls necklaces',
#  'al-rehab',
#  'counseling in session do not disturb sign',
#  'smalti mosaic tiles',
#  'curtains',
#  '60 birthday gifts',
#  'smartstraps bungee cords',
#  'ivory 90x156 tablecloth',
#  'ecollar mini',
#  'silhouette tools',
#  'christmas wreath',
#  '11x14 frames without glass',
#  'rock shot glasses',
#  '2 mg mini nicotine lozenges',
#  'restorapet for dogs',
#  'large geodes with crystals break your own',
#  'tinted reading glasses women',
#  'side table',
#  "I'm looking for a fully waterproof and windproof jacket with a padded lining a hood and ideally in dark green.  ",
#  'michael kors handbags',
#  'ugg scuffette',
#  'neck gaiter',
#  'monitor stand',
#  'murphy bed',
#  'cat tree without carpet',
#  'bed lap desk for laptop and writing',
#  'butt workout machine',
#  'asus replacement screen',
#  'foos ball coffee table',
#  'gaming headset',
#  '1-3/8 inch door bottom without drip cap',
#  'sofa recliner for living room',
#  'hulk bandana face mask',
#  'toothpaste without sweetner',
#  'outdoor rug',
#  'dresses',
#  'you shall not pass',
#  'tufted leather sofa',
#  'bread without gluten',
#  'do not give into the war within shirt',
#  'autell evo 2 hard case',
#  'mens black under armour socks',
#  'flonase nasal spray generic',
#  'pj mask clothes girls',
#  'tac pen as seen on tv',
#  'hiking backpack',
#  'a ring gold',
#  '10x10 gazebos for patios',
#  'fisher & paykel',
#  'bath mat',
#  'toys kitchen',
#  'pot with strainer lid',
#  'halloween books for kids',
#  'cali king duvet cover',
#  "mre's meals ready to eat military",
#  'cushions black and white',
#  'brown sandles womans',
#  'zinger wheel chair',
#  'le mini macaron nail kit',
#  "*i'm gaming do not disturb*shirt",
#  'file accordian organizer',
#  'mandrel tube benders',
#  'magnum white chocolate ice cream',
#  'gifts for women',
#  'post partum herbal sitz bath',
#  'stayfree pads ultra thin with wings',
#  'dizzy pig dust',
#  'macbook pro 13 inch case',
#  'men timberland boots',
#  'mens xxl compression socks',
#  'candy pink and blue',
#  'haus heavy duty',
#  '3lb dumbellsweights',
#  'futon sofa bed',
#  'citrus magic air freshener solid',
#  'A plain black, warm puffer jacket with a hood and decently sized pockets',
#  'appollon supplements',
#  'a5 ring binder',
#  'byredo hair perfume',
#  'widgets for crocs',
#  'ramyeon',
#  'air fryer',
#  'tob womens sexy criss cross',
#  'crossbody bags for women',
#  'erasable labels for containers',
#  '120ft led light',
#  'vegan whoopie pies',
#  'vanity pink and white',
#  'orquidias artificiales para decoracion',
#  "2' pink balloon",
#  '1-2-3 blocks without holes',
#  '10x10 umbrella square without base',
#  'zipper sweaters for women without hoodie',
#  'sillas plegables',
#  'wide ruled notebook paper',
#  'thank you condolence cards',
#  'swing sets for kids',
#  'wall beds & murphy bed queen',
#  'drive medical deluxe two button folding walker',
#  'huge sunglasses',
#  'bill counter machine mixed denomination',
#  'tacoma bed tie down',
#  'hydro flask',
#  'home office chair without wheels',
#  'nordic naturals cod liver oil',
#  'lobelia tea organic',
#  'alpine watches for men',
#  'fack piercings',
#  'mickey necklace for women',
#  'quaker rice cakes chocolate',
#  'hats grunt style',
#  'goggle face shield',
#  'im here live im not a cat',
#  '100 ftair hose reel without hose',
#  'aaa aa batteries combo',
#  'rivermoon coffee',
#  'cat turntable',
#  'chorme nails',
#  'mini rc cars for adults',
#  'baby blues hair vitamins',
#  'light blue intense dolce and gabbana women',
#  'graco classic connect car seat',
#  'music without wifi or internet',
#  'bralettes for women',
#  'jeep wrangler accessories',
#  'goat supplies',
#  'bow and arrow indoor without hole',
#  'halloween decorations',
#  'swimdress',
#  'bluetooth mouse',
#  'mens hey dudes size 8',
#  'casual tops for women plus size 3/4 sleeve',
#  'and1 shorts for men',
#  'board games',
#  'goggles without nose cover',
#  'girl night out party',
#  'kids makeup vanity for girls',
#  'tub wall mount high spout clawfoot tub faucet w/ handshower',
#  'gender not found',
#  'plus tops for women',
#  '0rgans only not piano for sale',
#  'squeaky tennis balls for dogs',
#  'vitamins for toddlers age 2',
#  'test blood sugar without pricking your finger',
#  'to shred bin',
#  'couch',
#  'kayak',
#  'highwaisted white jeans',
#  'vanity without top 48 inch',
#  'army green high waisted pants for women',
#  'little trees fresh shave',
#  'tall makeup chair',
#  'iwatch',
#  'phone holder for car',
#  'pink wristlet',
#  'bubba water bottle',
#  'iphone earbuds',
#  'industrial fan 12',
#  'candles bulk scented',
#  'halo newborn insert',
#  'amazon diamond rings for women',
#  'elemonate grey water deodorizer and tank cleaner',
#  'aztec earrings for men',
#  'twin bed frame without box spring',
#  'mask',
#  '104 inch curtain rod white without finnial',
#  'pa systems',
#  '1 1/4 well strainer for water well without foot valve',
#  'kitchen cabinets',
#  'red notebook wide ruled',
#  '4 pack ping pong paddles',
#  'black backpacks for teen girls',
#  'beach umbrella',
#  'tri picture frame',
#  'chacos women sandals',
#  'lemon fiber one bars',
#  '-3.50 not reading glasses',
#  'womens black high waisted bikini bottoms',
#  'no not hair net equestrian',
#  'do not cross belt',
#  'electrolyte powder without stevia',
#  'sls free toothpaste',
#  '1 acre bug zapper outdoor without octenal attractant',
#  '60" round dining table',
#  'games without internet',
#  'light pink nightstand lamp',
#  '10x7 patio gazebo with or without screen',
#  '20 by 30 by 1 air filter',
#  'rose tablecloth plastic',
#  'Dark blue denim jackets with a fluffy inside and collar similar to aviator jacket',
#  'vintage hair accessories for women',
#  'sail watch',
#  'board games',
#  'heat blankets electric',
#  'cycling shorts without padding',
#  'anime mask',
#  'yankee without brim',
#  'omega moonwatch',
#  'groceries ebt eligible snacks',
#  'cat treats without chicken',
#  'doterra frankincense',
#  'blanket french bulldog',
#  'electric clippers for men hair',
#  'drawing tablet',
#  'gold tennis bracelet set for women',
#  '- y not narural organic pharm oure enu oil',
#  'party glasses',
#  'washable watercolor paint kit',
#  'month by month stickers',
#  'puma pounce low cut socks',
#  'belly band holster left handed for men',
#  'halloween',
#  '4-16x44 rifle scope',
#  'tsum tsum stuffed animal',
#  'whole nature whole food multivitamin',
#  'b complex without vitamin c',
#  '.5 cc syringe without needle',
#  'vegan collagen powder',
#  'brown swivel bar stools',
#  'mask without ear straps',
#  'intertainment set',
#  'gaming chair without wheels',
#  'split phase inverter',
#  "engineer i'm not arguing",
#  'dog car protector',
#  'yes4all adjustable aerobic step platform',
#  'accent chair covers without arms',
#  '1 large white silk gardenia without stem',
#  'swissqlip deep carry pocket clip',
#  '10 by 10 pergola aluminum',
#  'catnoir toy',
#  'mini uv light for nails',
#  'men long sleeve tee shirts',
#  'habitant pea soup',
#  'ellora olive oil',
#  'bodysuit for women',
#  'amazon fire stick',
#  'kenneth cole unlisted mens dress shirt big and tall',
#  'matted picture frame',
#  'amp switch',
#  'gallon water bottle without straw',
#  'water',
#  '1 inch leather belt without buckle',
#  '90x132 gold satin tablecloth',
#  'beach pants high waisted',
#  'pound fitness sticks',
#  'camping chair',
#  "if i can't bring my dog, i'm not going",
#  'biden is not my you know... the thing',
#  'didlo large thick huge',
#  'velvet cream sofa set',
#  'when tomorrow starts without me',
#  'rv patio mats 9x20',
#  'unidus long love condoms',
#  'lego star wars',
#  '1 large white silk gardenia without stem',
#  'bosch 18v router',
#  'acurite wireless weather station',
#  'fluffy robes for women plush',
#  'gluten free dumpling wrappers',
#  'oakley turbine rotor lenses',
#  'under eye cream for dark circles',
#  'mens taupe pants',
#  'wicker floor lamps for bedrooms',
#  'surface go',
#  'rechargeable aa batteries',
#  'funny post it notes',
#  'rubber rafts for fishing 200$',
#  'pint one wheel',
#  'irestore laser hair growth system',
#  'external hard drive',
#  '0% sad without you tanktop',
#  'silver pendants without chain',
#  'pool table',
#  'freedom is not free t-shirt',
#  'books best sellers',
#  'stuffed foxes for kids',
#  'vibrators',
#  'well thats not a good sign tshirt',
#  'baseball pitching machine jugs',
#  'asl poster',
#  'boots for women',
#  'slowtide beach towel',
#  'blouses for women',
#  'womens columbia tamiami shirts long sleeve',
#  'stud welder',
#  'american flag joggers for men',
#  'porsche black touch up paint',
#  'metal blanket basket',
#  'vanessa rosella tote bag',
#  'decorative copper lights',
#  'jeep polo shirts for men',
#  '#5 zipper tape without pulls',
#  'prep h wipes flushable',
#  'macha green tea powder organic',
#  'i cannot live without books tshirt',
#  'len kagamine poster',
#  'dji drone phantom 4',
#  'fever tree',
#  'memory foam mattress topper',
#  'placemat cotton linen',
#  'abortion pills for pregnancy',
#  'teacher monthly calendar',
#  'bread without gluten',
#  '100” foot baby gate without attached',
#  '100 percent ginger oil',
#  'ceiling fan',
#  'belt for women guess',
#  'museum classic movado watch',
#  'olive green purses for women',
#  'dressmakers scissors',
#  'bath colors for toddlers non toxic',
#  '70 costumes for women',
#  'duke lanyard',
#  'acrylic paint',
#  '2x4 flat panel led light surface mount',
#  'common milkweed seeds',
#  'tape and mudding tools',
#  'rfid mens slim wallet',
#  'golf tees purple',
#  'white vanity',
#  '1 14 brown leather belt without buckle',
#  'andies mints',
#  'kindle',
#  'plus tops for women',
#  'best white noise machine for baby',
#  'braided bully stick red barn',
#  'chevrolet camaro accessories',
#  'xiao long bao',
#  'playtex bras for women wirefree',
#  'please do not flush anything except toilet paper sign',
#  'sweetart rope',
#  'my great aunt loves me baby clothes',
#  'fish scale rag--super absorbent without leaving marks',
#  'popcorn machine',
#  'dji drones',
#  'depends night defense medium for women',
#  'escrima cold steel',
#  'dog collar',
#  'n95 mask without valve',
#  'protein powder',
#  'drilling machine',
#  "11'+patio+umbrella without tilt",
#  'macbook pro',
#  'gucci handbags for women',
#  'combo guitar amplifier',
#  'kohler wall hung toilet',
#  'fluffy pink slippers',
#  'extra large drying rack for dishes',
#  'spring powered bb gun metal',
#  'kids swany gloves',
#  ...]

# %%
for query in ubi_user_queries[:10]:
    for id,team in run_AB(client, query, 'Demo 2', 'Demo 3'):
        events = get_events(client, id, query)
        count = events['hits']['total']['value']
        if count:
            print(f"{team} {query}, {id} => {count}")
# Out:
# TeamA surge protector power strip, B00TP1C51M => 2

# %%
for query in ubi_user_queries[:100]:
    for id,team in run_AB(client, query, 'Demo 2', 'Demo 3'):
        count = count_clicks(client, id, query)
        if count:
            print(f"{team} {query}, {id} => {count}")
# Out:
# TeamA pokemon, B07DMFDC6W => 9
# TeamB ipod touch, B07FM5Z5C3 => 21
# TeamA 30 inch ceiling fan without light, B001JBPHRU => 7

# %%
query_set_df = pd.DataFrame(ubi_user_queries, columns=['query'])
query_set_df
# Out:
#                                        query
# 0                                   vibrator
# 1                           weighted blanket
# 2                                apple watch
# 3                                  air fryer
# 4                surge protector power strip
# ...                                      ...
# 9964                   metal razor for women
# 9965      metagenics phytomulti without iron
# 9966  wheelchair cushions for pressure sores
# 9967                            barbie dolls
# 9968                  lifevac choking device
#
# [9969 rows x 1 columns]

# %%
query_set_df['res'] = query_set_df['query'].apply(lambda x: [ (id, count_clicks(client, id, x), team) for id,team in run_AB(client, x, 'Demo 2', 'Demo 3')])
query_set_df = query_set_df.explode('res')

# %%
query_set_df = query_set_df.join(pd.DataFrame(query_set_df['res'].values.tolist(), columns=['id', 'clicks', 'team']))
query_set_df
# Out:
#                        query                     res          id  clicks  \
# 0                   vibrator  (B07GZHJ3NL, 0, TeamA)  B07GZHJ3NL     0.0
# 0                   vibrator  (B07F9RR8PN, 0, TeamB)  B07GZHJ3NL     0.0
# 1           weighted blanket  (B097DWWTLM, 0, TeamA)  B07F9RR8PN     0.0
# 1           weighted blanket  (B075W9VSW7, 0, TeamB)  B07F9RR8PN     0.0
# 1           weighted blanket  (B07C9N1GXD, 0, TeamA)  B07F9RR8PN     0.0
# ...                      ...                     ...         ...     ...
# 9968  lifevac choking device  (B07P5TTMLJ, 0, TeamA)  B07G5VLVNM     0.0
# 9968  lifevac choking device  (B00TRM0UI4, 0, TeamB)  B07G5VLVNM     0.0
# 9968  lifevac choking device  (B01MSWT7H7, 0, TeamA)  B07G5VLVNM     0.0
# 9968  lifevac choking device  (B07L4BFQBK, 0, TeamA)  B07G5VLVNM     0.0
# 9968  lifevac choking device  (B01N7X25EN, 0, TeamB)  B07G5VLVNM     0.0
#
#        team
# 0     TeamA
# 0     TeamA
# 1     TeamB
# 1     TeamB
# 1     TeamB
# ...     ...
# 9968  TeamA
# 9968  TeamA
# 9968  TeamA
# 9968  TeamA
# 9968  TeamA
#
# [96260 rows x 5 columns]

# %%
query_set_df[query_set_df['team'] == 'TeamA'].describe()
# Out:
#              clicks
# count  47991.000000
# mean       0.019795
# std        0.459468
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       17.000000

# %%
query_set_df[query_set_df['team'] == 'TeamB'].describe()
# Out:
#              clicks
# count  48038.000000
# mean       0.022378
# std        0.550752
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       21.000000

# %%
query_set_df[query_set_df['team'] == 'TeamA'][query_set_df[query_set_df['team'] == 'TeamA']['clicks'] > 0]
# Out:
#            query                     res          id  clicks   team
# 267    desk lamp  (B08R3HB3QB, 0, TeamA)  B07DMFDC6W     9.0  TeamA
# 267    desk lamp  (B072PS1YBH, 0, TeamB)  B07DMFDC6W     9.0  TeamA
# 267    desk lamp  (B01M4NPL9Z, 0, TeamA)  B07DMFDC6W     9.0  TeamA
# 267    desk lamp  (B07G8SCB99, 0, TeamB)  B07DMFDC6W     9.0  TeamA
# 267    desk lamp  (B01JFRX3FC, 0, TeamA)  B07DMFDC6W     9.0  TeamA
# ...          ...                     ...         ...     ...    ...
# 9384  baby dolls  (B005537IFW, 0, TeamB)  B00HD0ELFK     8.0  TeamA
# 9384  baby dolls  (B004QPEWVS, 0, TeamA)  B00HD0ELFK     8.0  TeamA
# 9384  baby dolls  (B07RP7JWNM, 0, TeamB)  B00HD0ELFK     8.0  TeamA
# 9384  baby dolls  (B095LF377Q, 0, TeamB)  B00HD0ELFK     8.0  TeamA
# 9384  baby dolls  (B005G14SGU, 0, TeamA)  B00HD0ELFK     8.0  TeamA
#
# [120 rows x 5 columns]

# %%
query_set_df[query_set_df['team'] == 'TeamB'][query_set_df[query_set_df['team'] == 'TeamB']['clicks'] > 0]
# Out:
#                                              query                     res  \
# 366                     yoga swing without handles  (B000BPBXL4, 0, TeamB)
# 366                     yoga swing without handles  (B076ZY2438, 0, TeamA)
# 366                     yoga swing without handles  (B07CGP4SB2, 0, TeamA)
# 366                     yoga swing without handles  (B01JH4J90G, 0, TeamB)
# 366                     yoga swing without handles  (B07B1RXDGQ, 0, TeamA)
# ...                                            ...                     ...
# 8044  10 x 20-feet pop up canopy without sidewalls  (B000BPBXL4, 0, TeamA)
# 8044  10 x 20-feet pop up canopy without sidewalls  (B01D7VBKQG, 0, TeamB)
# 8044  10 x 20-feet pop up canopy without sidewalls  (B083CBCQL1, 0, TeamA)
# 8044  10 x 20-feet pop up canopy without sidewalls  (B0119Q7J48, 0, TeamB)
# 8044  10 x 20-feet pop up canopy without sidewalls  (B08MPZ9BLN, 0, TeamB)
#
#               id  clicks   team
# 366   B07FM5Z5C3    21.0  TeamB
# 366   B07FM5Z5C3    21.0  TeamB
# 366   B07FM5Z5C3    21.0  TeamB
# 366   B07FM5Z5C3    21.0  TeamB
# 366   B07FM5Z5C3    21.0  TeamB
# ...          ...     ...    ...
# 8044  B07XFR5M5G     1.0  TeamB
# 8044  B07XFR5M5G     1.0  TeamB
# 8044  B07XFR5M5G     1.0  TeamB
# 8044  B07XFR5M5G     1.0  TeamB
# 8044  B07XFR5M5G     1.0  TeamB
#
# [117 rows x 5 columns]

# %%
query_set_df[query_set_df['team'] == 'TeamB'][query_set_df[query_set_df['team'] == 'TeamB']['clicks'] > 0].describe()
# Out:
#            clicks
# count  117.000000
# mean     9.188034
# std      6.377400
# min      1.000000
# 25%      3.000000
# 50%      7.000000
# 75%     14.000000
# max     21.000000

# %%
query_set_df[query_set_df['team'] == 'TeamA'][query_set_df[query_set_df['team'] == 'TeamA']['clicks'] > 0].describe()
# Out:
#            clicks
# count  120.000000
# mean     7.916667
# std      4.700408
# min      2.000000
# 25%      4.500000
# 50%      7.000000
# 75%      9.750000
# max     17.000000
