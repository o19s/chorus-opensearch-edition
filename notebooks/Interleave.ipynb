# %%
import numpy as np
import pandas as pd
import random
import json
from opensearchpy import OpenSearch
import os
OPENSEARCH_HOST = os.getenv("OPENSEARCH_HOST", "localhost")
OPENSEARCH_PORT = os.getenv("OPENSEARCH_PORT", 9200)

# %%
def interleave(listA, listB, k):
    ids = []
    teams = []
    rank = 1
    idx_a = 0
    idx_b = 0
    len_a = len(listA)
    len_b = len(listB)

    while rank <= k:
        a_val = listA[idx_a]['_id'] if idx_a < len_a else None
        b_val = listB[idx_b]['_id'] if idx_b < len_b else None
        if not (a_val and b_val):
            # lists are done
            return zip(ids, teams)
        if not a_val:
            # take the rest of listB
            for hit in listB[idx_b:k]['_id']:
                if hit not in ids:
                    ids.append(hit)
                    teams.append('TeamB')
            return zip(ids, teams)
        if not b_val:
            # take the rest of listA
            for hit in listA['_id']:
                if hit not in ids:
                    ids.append(hit)
                    teams.append('TeamB')
            return zip(ids, teams)
        a_first = idx_a < idx_b or idx_a == idx_b and random.randint(0,1)
        if a_first:
            if a_val not in ids:
                ids.append(a_val)
                teams.append('TeamA')
                rank += 1
            idx_a += 1
        else:
            if b_val not in ids:
                ids.append(b_val)
                teams.append('TeamB')
                rank += 1
            idx_b += 1       
    return list(zip(ids, teams))


def get_list(listA, listB, k):
    A = listA['hits']['hits']
    B = listB['hits']['hits']
    interleaving = interleave(A, B, k)
    return interleaving

def get_search_config(client, name):
    search_configs_index = 'search-relevance-search-config'
    conf = client.search( body = {
      "query": {
        "match": {"name": name}
      },
      "size": 1
    }, index=search_configs_index)
    return conf['hits']['hits'][0]['_source'] if len(conf['hits']['hits']) else {}

def populate_query(query, config, size=10, source=["title", "description", "asin"]):
    query = query.replace('"', '\\"')
    body = json.loads(config['query'].replace("%SearchText%", query))
    body['size'] = size
    body['_source'] = source
    return body

def run_AB(client, query, configA, configB, size=10):
    confA = get_search_config(client, configA)
    confB = get_search_config(client, configB)
    qA = populate_query(query, confA, size=size)
    qB = populate_query(query, confB, size=size)
    #TODO: extract the endpoint value from the search config, rather than using the client here
    resA = client.search(body=qA)
    resB = client.search(body=qB)
    result = get_list(resA, resB, 10)
    return result

def get_events(client, id, query, event_type=None):
    if event_type:
        evq = {
          "query": {
            "bool": {
             "must": [   
                 {"match": {"event_attributes.object.object_id": id}},
                 {"match": {"user_query": query}},
                 {"match": {"action_name": event_type}}
             ]
            }
          },
          "size": 1000
        }
    else:
        evq = {
          "query": {
            "bool": {
             "must": [   
                 {"match": {"event_attributes.object.object_id": id}},
                 {"match": {"user_query": query}}
             ]
            }
          },
          "size": 1000
        }
    results = client.search(body=evq, index='ubi_events')
    return results

def get_clicks(client, id, query):
    results = get_events(client, id, query, 'click')
    return results

def count_clicks(client, id, query):
    results = get_clicks(client, id, query)
    return results['hits']['total']['value']

# %%
# Create the client with SSL/TLS and hostname verification disabled.
client = OpenSearch(
    hosts = [{'host': OPENSEARCH_HOST, 'port': OPENSEARCH_PORT}],
    http_compress = True, # enables gzip compression for request bodies
    use_ssl = False,
    verify_certs = False,
    ssl_assert_hostname = False,
    ssl_show_warn = False
)

# %%
ubi_queries = client.search(body={'query': {'match_all': {}}, "size":10000}, index='ubi_queries')
ubi_user_queries = [x['_source']['user_query'] for x in ubi_queries['hits']['hits']]
ubi_user_queries
# Out:
# ['canned tuna solid white albacore water',
#  'vitamin e oil without soy',
#  'bikini high waisted',
#  'budha mural wall art',
#  'adidas golf shoes men',
#  'and pepper shaker',
#  'bee traps outdoor hanging',
#  'leather sofas for living room',
#  'scetchpad for drawing',
#  '115 piece drill bit index without drill bits',
#  'clif bars cool mint chocolate',
#  'clock',
#  'outdoor fans without lights',
#  'planters for outdoor plants',
#  'calcium supplements without vitamin d',
#  'dimplex ignite xl 74',
#  'resin patio chairs',
#  'yeti',
#  'ffp2 mask without valve',
#  'gaming monitor',
#  'round baking pans',
#  'mct oil without lauric acid',
#  'mouthguard toothbrush for adults',
#  'japan deep frying pan',
#  'hoppes bore snake 9mm pistol',
#  'little ikes turn slide',
#  'floating rafts for ocean',
#  'albany park sofa',
#  'sipsnap',
#  'magnified lighted mirror',
#  'red green yellow party decorations',
#  'maritini glasses',
#  '6 x 12 floor register oil rubbed bronze',
#  'boys nautica shorts',
#  'foam roller',
#  'black teddy jacket',
#  'ling ling potstickers',
#  'casual shirts for men',
#  'long sleeve green shirts',
#  '3x cotton shirts for men',
#  'detergent without bleach',
#  'russbe reusable bags',
#  'buffalo david bitton kids',
#  'better not younger',
#  'car charger',
#  'plus size formal dresses and gowns',
#  'grass mats for outdoors',
#  'pocket squares for men',
#  'plus size wedding pant suits',
#  '10 seat outdoor table and chairs without umbrella',
#  '5xl sweatpants for men big and tall',
#  'back supports and braces',
#  'vinyl white and black',
#  'bathtub mats non slip mildew resistant without suction cups',
#  '1oz glass spray bottles',
#  'antiseptic wipes individually wrapped',
#  'ban idiots not guns',
#  'cuddler sectional',
#  'best vitamins for women 30',
#  'kindle books',
#  "levi's 311 shaping skinny jeans",
#  'cushions black and white',
#  'xbox',
#  'ps4 headset',
#  '2 1/2 hose reducer',
#  'cosas de escritorio',
#  'portable duckboards',
#  'urinary probiotic for women',
#  'rgb lights for room',
#  '1 1/2” wide mens belt without buckle',
#  'yosposs',
#  'calcium mineral supplements',
#  'craft ribbon storage organizer rack',
#  'hoodie blankets for teen girls',
#  'dress deep v neck sexy',
#  "11'+patio+umbrella without tilt",
#  'megaesophagus dog',
#  'quincy compressor pump',
#  'huggies little snugglers size 3',
#  '.rascal does not dream of bunny girl senpai tapestry',
#  'isolyze protein',
#  'turtle stuffed animals plush toys',
#  'puge mask',
#  'purple dice for car mirror',
#  'a19 color changing light bulb',
#  'lawn flamingos bulk cheap',
#  'cruise tote bag',
#  'batteries',
#  'security blanket',
#  'table top white board easel',
#  'circa watches',
#  'hot wheel colossal crash track set',
#  '2t long sleeve boys',
#  '(zero) days without a bad dad joke',
#  'flip art kit',
#  'patagonia womens',
#  'i cant tie the knot without you cards',
#  'cash out but not a quitter',
#  '24v bow mount trolling motor',
#  'kremotex new anti aging cream',
#  'surface go',
#  '1 oz plastic shot glasses without lids',
#  'barnett ghost 360 crossbow',
#  'dewalt 745 table saw',
#  '4 oz spray bottle',
#  'fun size candy variety pack',
#  '1 wine glasses without stems',
#  'christmas ornaments red and silver',
#  'retirement gift',
#  'tie strap dress for women',
#  'if youre not first youre last shirt',
#  'ibuki wig without horns',
#  'gold decorative wall hooks',
#  'gustus vitae spices',
#  'burial urns for adult human ashes',
#  '24 foam roller for physical therapy & exercise',
#  'small puerto rican flag',
#  'reef phantom flip flops men',
#  'f11 topcoat',
#  'gift boxes without lids',
#  'bowflex bar attachment',
#  'ja morant jersey',
#  'twinkle little star party decorations',
#  'rume bags grocery',
#  'king size bed spreads not comforters',
#  'atn binox 4k 4-16x',
#  'simply cheetos puffs white cheddar',
#  'paisley blouses for women',
#  'bartty pack charger for car',
#  'large pink christmas ornaments',
#  'dreidel',
#  '7x5 notebook spiral',
#  'learning without tears',
#  'chair covers for office chairs without arms',
#  'wireless charger',
#  '45x53 chair mats for carpeted floors',
#  'kids makeup vanity for girls',
#  'new age 30 garage storage cabinets',
#  'inhaler spacer for adults without mask',
#  'octupus reversed plushie pink and blue',
#  'nursing tops',
#  'dumbbells set with rack',
#  'dior rose gold sunglasses',
#  'mens 5xlt shirts big and tall',
#  'seven oceans food',
#  '12v transformer led light',
#  '1 cup scoop without handle',
#  'black woven storage basket',
#  'window tint see out but not in',
#  'booty fresh for women',
#  'tiny homes for sale',
#  'mickey necklace for women',
#  'grid mirror',
#  "cat puns freak meowt - seriously i'm not kitten shirt",
#  'boys diary with lock and key',
#  'satco lightbulb',
#  'framed album covers',
#  'my parents did not practice social distancing onesie',
#  'far red led grow light',
#  'dog harness for large dogs',
#  'thomas the train',
#  'grill',
#  'mirror with lights',
#  'midliner brush pens',
#  'no beer not going shirt',
#  'jura giga 6',
#  'the first but not the last',
#  'drs best high absorption magnesium',
#  'hair dye without ppd and ammonia',
#  'seasonal garden flags',
#  'outdoor basketball nets',
#  'oris watches men',
#  'kayak roof rack',
#  'nintendo switch games',
#  'weighted blanket without beads',
#  'thin mens tshirts',
#  'jjba earrings',
#  'yozuri bonita wahoo lure',
#  'echo dot 3rd gen',
#  'bulk lunch bags',
#  'mascara hypoallergenic sensitive eyes',
#  'cupshe high waisted tankini',
#  'private property not for sale',
#  'boyfriend capris for women loose fit',
#  'copal essential oil',
#  'v neck white t shirt women',
#  '+women red shoes without lacies',
#  'cork and white board combo',
#  'small boys underwear',
#  'triglyceride lowering supplements',
#  'vionic ballet flats for women',
#  'airpod case',
#  "gold men's ring diamonds",
#  'vermont american drill bit set',
#  'xxx',
#  'black floral tapestry',
#  'parker rollerball refill blue',
#  'yogurt greek whole milk',
#  'ratchet belts for men without buckle',
#  'back seat mirror without headrest',
#  'clarified butter not ghee',
#  'bath aids for disabled and elderly',
#  'narrow nightstand',
#  'modern sleep adjustable bed',
#  '11x13 white frame without mat',
#  'rolled gold pretzel sticks',
#  '08 f250 mirrors without lights',
#  'stickers without white outline',
#  'king size sheets not microfiber',
#  'mens black under armour socks',
#  'golden doodles merchandise funny',
#  'wood desk chairs without wheels',
#  'underarmour pants for men',
#  'barking spray for dogs',
#  'welder nation welding caps',
#  'punjabi salwar suits simple classy',
#  'do not bend sticker',
#  'white adirondack chairs',
#  "i's not a dad bod, it's a father figure",
#  'hard drive',
#  '32x80 exterior solid door',
#  'nasa beanie for men',
#  'bamboo wood utensils',
#  'error 404 costume not found',
#  'puma training shoes men',
#  'couch l shape leather',
#  '3 day refresh beachbody without shakeology',
#  'laundry hamper without lid',
#  '34 curvy jeans',
#  'tru ball short n sweet',
#  'wusthof knife set without block',
#  'jordans skinny syrups sugar free',
#  'loft bed without desk',
#  'dior show volume mascara',
#  'long oven mitts heat resistant 500 degrees',
#  'kids farm boots for girls',
#  '84 inch bathroom vanity',
#  'dogs make me happy you not so much',
#  'umbrella upside down',
#  're grow my hair',
#  'blackout+tights+for+women',
#  'high waist skinny jeans for women',
#  '2 1/2 hose reducer',
#  'boon drying rack large',
#  'of course your opinion matters just not to me',
#  'hydro flask',
#  'bathroom freshener long lasting',
#  'tires',
#  'hamilton watches for men',
#  'kids mask around head not ears',
#  'drums not guns',
#  'make love not war shirt',
#  'mini snack dispenser',
#  'two piece bedroom drawer',
#  'simply delish sugar free pudding',
#  'abcd puzzles',
#  'car slim jim kit',
#  'patpat baby girl',
#  'best tweezers for eyelash extension - straight and curved',
#  'squat proof high waisted leggings',
#  '12 speed groupset',
#  'lashes not too long',
#  'girls invented punk rock not england shirt',
#  'pillow without stuffing',
#  'new england patriots shirts for women',
#  'hakone yosegi',
#  "mens i'm not sleeping i'm just resting my eyes dad shirt",
#  'automatic espresso machine jura',
#  'summit white touch up paint chevrolet',
#  'taco stand up holders',
#  'telescopic back scratchers for adults extendable',
#  'pillow without stuffing',
#  "women's rash guard shirts",
#  'no chicken soup',
#  'wireless thermostat without c wire',
#  'rog phone 2',
#  'high school english',
#  'eye drops for dry eyes without preservatives',
#  'blackfly sunglasses men',
#  'chaircushions',
#  'oreos without cream',
#  'q link pendants',
#  'teens period kit',
#  'laundry carts baskets with wheels',
#  'hoodie blankets for teen girls',
#  'yeti for kids',
#  'magnetic dry erase white board',
#  'pantyhose support for women',
#  'american flag and wooden pole set for house',
#  'san marco graduated necklace',
#  'light blue work shirt',
#  'cactus outdoor decor',
#  '100 oz water bottle bpa free',
#  'ikea kallax insert',
#  'scrub caps women',
#  'i do not spew profanities mug',
#  '18k gold studs for men',
#  '1 ft 3/8 not hose',
#  'white magnetic board for kids',
#  'dry erase markers',
#  'high chair without fabric',
#  'breguet watches',
#  'ffp2 not kn95',
#  'goodthreads long sleeve slim fit',
#  '1/2oz amber bottle without lid',
#  'retro green throw pillows',
#  'trending mens fashion',
#  'floral dessert plates',
#  'donut shop dark coffee k-cup',
#  'gift not included batteries',
#  'dorothy wizard of oz',
#  'womens straight leg yoga pants',
#  'air nike jordan 1',
#  'iphone 7 plus case',
#  'olay active hydrating beauty fluid lotion - original',
#  'white fold dianobd earribgs screw bacj',
#  'love is not cancelled',
#  'vanity fair panties illumination',
#  'sconces wall lighting set of 2',
#  'yoga mat',
#  'gel nail polish without uv light needed',
#  'ibc tote vc',
#  'cliff bars white chocolate macadamia nut',
#  'reclining sofa with console',
#  'carro control remoto',
#  'just a regular mom trying not to raise',
#  'jeep wrangler accessories',
#  'lounge dress for women loose fit',
#  'i enjoy not having polio',
#  '1 inch wooden beads for crafts without holes',
#  'your baby can learn deluxe kit',
#  'dutch processes cocoa powder',
#  'curtain rod without drilling for windows',
#  '0.35x 0.5 stainless steel u not h trowel',
#  'jms580',
#  'uti over the counter',
#  '$10 amazon prime not prime wardrobe sweatpaants',
#  'gogo yubari costume',
#  'double ended markers not brush',
#  'muslim fashion hijab outfits',
#  '100% egyptian cotton sheets king',
#  'stand up heaters for garage',
#  'womens swimsuits',
#  'chair',
#  'gray away medium brown',
#  '24 oz plastic cups with lids',
#  'light bulbs',
#  'pompas floral with vase',
#  'bird shooting gun',
#  'four paws magic coat instant dog mat remover',
#  'kaenon sunglasses for men',
#  'badges without borders',
#  '118x98 oversized king without detail plain white comforter',
#  'metrx big 100',
#  "cat puns freak meowt - seriously i'm not kitten shirt",
#  'flash drive',
#  'dog long lasting chew toys',
#  'kt fancy 16 piece american doll accessory suitcase',
#  'dual door knob',
#  'nature does not hurry, yet everything is accomplished.',
#  'a gaming set up',
#  'trim you spray weight loss',
#  'black 5x7 frame',
#  '1 for 1 chlorine free pads without wings',
#  '3d printer',
#  'sequential discovery puzzle',
#  'camo pants women high waisted cargo',
#  'facecream women day',
#  'santa bags canvas sacks large christmas',
#  'usb c cable',
#  'alexa',
#  'lighting without electricity',
#  '10 stickers',
#  'blender',
#  '10 gage electrical wire without ground',
#  'bug activities for kids',
#  'small skull mold',
#  'lashes not too long',
#  'black cat eyed sunglasses for women',
#  'leupold scout scope',
#  'compression socks without feet women',
#  "women's sweatshirts without hoods",
#  'baby shower mint molds',
#  'garden watering wand nozzle',
#  'vintage peg votive candle holders',
#  '1 1/2 sink drain without overflow',
#  'hydrocolloid dressing without border',
#  'mtm gun case',
#  'office chair',
#  'sholders support',
#  'twin xl comforter sets for college girls',
#  'reclaim it insecticide',
#  'chromebook',
#  'gamma ray blue light blocking glasses',
#  'im not throwing away my shot',
#  'pink outfits for women',
#  "mother's ring",
#  'farmhouse industrial lighting',
#  'dried sour cherries',
#  'posture corrector for women',
#  'rigid pro pack',
#  'hallmark shoebox funny christmas cards',
#  'funko pop chester cheetah',
#  'light bulb changer for high ceilings with pole',
#  'italica motorcycle',
#  'infant changing pad',
#  'oil rubbed bronze tub spout without diverter',
#  'safety 1st stay clean humidifier',
#  'disguised password book',
#  'flat iron for hair',
#  'iron beads ideas design',
#  '3inch memory foam mattress topper queen',
#  'paper shredder',
#  'xylophoney',
#  '72 inch freestanding bathtub',
#  'great white mycorrhizae',
#  'lamy dark lilac ink',
#  'energizer aa rechargeable batteries',
#  'kp lotion',
#  'floor mat alarm for elderly',
#  'tote beach large',
#  'ruler with metric and standard',
#  '2 piece high waisted swimsuits for women tankini',
#  'nah not today',
#  'jeans american eagle for men',
#  'silver yin yang ring',
#  'debuyer',
#  'single bottle wine chiller',
#  'pinty scope',
#  'iphone xs max',
#  'adult toothpaste not mint',
#  'hammocks for outside without stand',
#  'bord games',
#  'boiled egg cooker without the shell',
#  'frye key fob',
#  'tiny homes for sale',
#  'sealy queen mattresses',
#  'plum eyeshadow matte',
#  'catty without coffee mug with spoon',
#  'luxebiotics dark circle & puffiness under-eye serum',
#  '1 inch 3 ring binder without clear pocket',
#  'musashi miyamoto figure',
#  'golf tees purple',
#  'nudie posters sexy uncensored',
#  'long work out shirts for men',
#  'pull on cotton pants',
#  'prada handbags for women',
#  '#3 metal zipper slider not made in america',
#  'toiletries travel bag men',
#  'ginger jar blue and white',
#  'alexa',
#  'just loud not fast shirt',
#  'duckbill masks n95 made in usa',
#  'gym sweatshirt men',
#  'personal lubricant without parabens',
#  'weighting comforts weighted blanket',
#  '11 ft umbrella without tilt',
#  'mtb frame protector',
#  'gate control remote',
#  'r initial diamond jewelry bracelet',
#  'arm and hammer essentials natural deodorant',
#  'friends not food',
#  '#followme ultra soft velour robe without hood for men',
#  'boho floating shelves',
#  'ring',
#  'xoxo watches for women',
#  'bible tabs old and new testament',
#  'kama weapon',
#  'moissanite diamond ring',
#  'baby treat bags',
#  'july charms',
#  'weighted blanket without beads',
#  'army face mask with filter',
#  'ethical coffee pods',
#  'outdoor carts for patio',
#  'natural spray sunscreen',
#  'navy blue bathroom towel set',
#  'lol themed birthday party decorations',
#  'boots without heels for women',
#  'ocusoft lid scrub plus',
#  'toy for 12 year old boy',
#  'The laptop I would like would be a sleek, silver Apple Macbook Pro.',
#  'light bulb changer for high ceilings with pole',
#  'difusor essential oil 2 pack',
#  'protein powder without sugar',
#  'halter ruffle dress',
#  'insulated tumblers for women',
#  'absolutely not woke shirt',
#  'the year without a santa claus heat miser t-shirt',
#  'doubles sided tape',
#  'buttoned down slim fit',
#  'debuyer',
#  'english standard version bible large print',
#  'hublot womens watch',
#  'sewing basket without accessories',
#  'earbuds',
#  'calcium supplements without vitamin d',
#  'multivitamin without vitamin a',
#  '1 inch leather belt without buckle',
#  'copeland furniture',
#  'snacks healthy organic',
#  '1 1/2 leather belts without buckle',
#  'carports kits',
#  '24 oz plastic cups with lids',
#  'grinking glasses',
#  'rimmel lip gloss',
#  '&#34;tortillas without interesterified soybean oil”',
#  'hoodies black and white',
#  'tactical sunglasses for men military polarized',
#  'defibrillator',
#  'different not less shirt',
#  'jump rope',
#  'tomy big farm',
#  'fuji white paint',
#  'hitachi demolition hammer',
#  'steak knife holders without knives',
#  "''im not retired im a professional grandpa'' shirt",
#  '74 curtain rod',
#  'delta toddler bed',
#  'st ives pink lemon and mandarin orange scrub',
#  'yogurt greek whole milk',
#  'divided kids plates',
#  'dont tread on me stickers',
#  'pure cedarwood oil',
#  'navy blue christmas ornaments',
#  'black cohosh supplements',
#  'breadsticks bulk',
#  'fender deluxe reverb',
#  'rolex women',
#  'its colombai not columbia',
#  '(hue2 lighting controller not included)',
#  'cocktail cherries old fashioned',
#  '4 oz spray bottle',
#  'swimsuits women high waisted two piece',
#  'ladies pink motorcycle jacket',
#  'church dress suits for women',
#  'grapes green seedless',
#  'open tow booties for women',
#  'polar black cherry',
#  'panties for women',
#  'car adapter to wall outlet',
#  '80 x 32 inch barn door',
#  'really ripped jeans for women',
#  'christmas ornaments white and gold',
#  'stars without number rpg',
#  'weighted blanket without glass beads',
#  'treadmill',
#  'vetri-liver canine',
#  '14/3 extension cord',
#  'nautica big and tall',
#  'adidas leggings women high waisted',
#  'srt keychain',
#  'pictorico pro ultra premium ohp transparency film',
#  'natural vitamins for anxiety',
#  '16mm pink glass beads',
#  '1 square container without lids small',
#  'jura giga 6',
#  'jean with elastic waist for women',
#  'halloween treats bulk',
#  'mat man handwriting without tears set',
#  'adjustable rings set',
#  'oculus quest',
#  'cute fall sweaters',
#  'swimsuits women high waisted two piece',
#  'headphones with microphone',
#  'euclyptus plant',
#  'nicetown thermal insulated blackout curtains',
#  'mens brown leather coats and jackets',
#  'gym shirts men',
#  '14k gold charm bracelets',
#  'wall desks for small spaces',
#  'isopods and springtails live',
#  'omega moonwatch',
#  'sprinkler without hose',
#  'office chair',
#  'gucci inspire watches',
#  'cruise tote bag',
#  '365 fruit bars',
#  'gucci purses for women',
#  'sexy bras without underwire',
#  'hbo',
#  'desk',
#  'cup and saucer display stand',
#  'external hard drive',
#  'ruger american compact 45 holster',
#  'boys mini backpack marvel',
#  '100” cutain rod without center support',
#  'tennis skirts without shorts',
#  'mens black and white striped shirt',
#  'cute womens tops',
#  '10 knife block without knives',
#  'matt black shower set',
#  'spa beds & tables',
#  'solid jersey sheet set',
#  'pictorico pro ultra premium ohp transparency film',
#  '1 oz tin without lid',
#  'mens slippers',
#  'em sculpting machine professional',
#  'black mens dress shirt slim fit',
#  'larsen cello strings soloist',
#  'xlr splitter 2 female 1 male',
#  'gel nail polish gold glitter',
#  'cedar elevated garden beds',
#  'fill in powder with procapil medium brown',
#  '80s theme party decorations for adults',
#  '1 white fancy box without a lid in living room',
#  'poly vi sol multivitamin infant without iron',
#  'migraine relief',
#  'oval velvet ring box',
#  'hair spray bottle',
#  'bose karaoke system',
#  'dog water bottle',
#  '10 men sexy lingerie without leg',
#  'doggie bags for poop biodegradable',
#  'badges without borders',
#  'fake plants without pot',
#  '10 pk curtain tie backs without hooks',
#  ', fidget do not yell at that cost $1',
#  'kalashnikov airsoft',
#  '11x14 frame without mat',
#  'patio furniture',
#  'cowboy decorations party',
#  'delgaden pm',
#  'macbook pro',
#  'pocket folders without prongs',
#  'sprayground backpack',
#  'taylor ham pork roll',
#  'all black nike shoes for women',
#  'fursuit wolf',
#  'manilla envelopes 10x13',
#  'you may not know me but i got your 6 shirt',
#  'iphone adapter',
#  'jabba the hutt',
#  '100 brown bags without handles',
#  'v neck white t shirt women',
#  'b complex without vitamin c',
#  'big drawing kit',
#  'i would be lost without you',
#  'plum eyeshadow matte',
#  'one for whom food is not enough',
#  'gig bag acoustic guitar',
#  'lawn flamingos bulk cheap',
#  'couch pillows set of 4',
#  '3x shorts for men big and tall',
#  '1/4 polyester boning without casing',
#  'dinnerware sets without mugs',
#  'engaged champagne flutes',
#  'ecko shirts for men',
#  'tortillas without interesterified soybean oil”',
#  'nordic naturals cod liver oil',
#  'wall bed with desk',
#  'boho patio furniture',
#  'plus clothing',
#  'back seat mirror without headrest',
#  '4x8 bubble mailers pink',
#  '48 round dining table',
#  'hang posters without damaging walls',
#  'nitrile gloves',
#  'loreal age perfect day cream',
#  'nautica polo shirts for men',
#  '6 piece extra deep pocket queen sheet set',
#  'curtain rod',
#  'junior hoodie',
#  'goggles without nose cover',
#  'black diamond engagement ring pear',
#  'date night outfits for women',
#  'eye drops for dry eyes preservative free',
#  '4 wheel mobility scooter',
#  'simple human g bags',
#  'extra large packing cubes for travel',
#  'vileda bath magic bathroom and tub mop',
#  'jnh chromotherapy light for sauna',
#  'man spider costume',
#  'cbd oil not hemp',
#  'incredibites dog food for small dogs',
#  'electric power auger',
#  'jeans mens slim fit',
#  'nope not today',
#  'loft bed without desk',
#  'soft scrub without bleach',
#  'boys rash guard short sleeve',
#  'womens open back workout top',
#  'champion t shirts for men big and tall',
#  'toys kitchen',
#  "'m team jesus i'm not religious shirt",
#  'inside holster for sig sauer p226',
#  'educational toys for 2 year old boys',
#  'fortnite',
#  'urinary probiotic for women',
#  'fabric thread cutter',
#  'bathroom rugs white washable',
#  'hawaiian shirts for women',
#  'big blue 4.5 x 10 filter',
#  'im here live im not a cat',
#  'light blue christmas tree',
#  'blue amazon vest',
#  '12x16 shed plans with garage door',
#  'lark & ro tops',
#  'teething puppy chew toys',
#  'magnets',
#  '1 big plastic bin with lid not clear',
#  'nordic naturals ultimate omega 3 fish oil',
#  'small wood box 12x18x8 not shadow',
#  'gray woven baskets',
#  'cotton high cut underwear for women',
#  'simple arabic mehndi designs easy back',
#  'x treme epdm bands',
#  'irestore laser hair growth system',
#  'dress deep v neck sexy',
#  'boho tree topper',
#  'loui vuitton',
#  'hibbett sports',
#  'gg collection',
#  'a true friendship is a journey without an end',
#  'car carriers rooftop without rack',
#  'piano accessories',
#  'oval diamond ring',
#  '.8 beading wire plastic not stretchy',
#  'marshmallows without gelatin',
#  'baby bottle mam',
#  'baby irish clothes',
#  'kayak hooks for garage',
#  'bookends decorative unique',
#  'dog diapers male xlarge disposable',
#  'egg slicer for hard boiled eggs',
#  'patio furniture',
#  'fibo steel',
#  'sofa',
#  'tall white bookshelf with cabinet',
#  'wusthof knife set without block',
#  '3 month green hat',
#  'floral baseball tee',
#  'vanity mirror without lights',
#  'yankees mariano rivera jersey',
#  'women sexual enhancement pills',
#  'spring flags for outdoors 28 x 40 double sided',
#  '1.75 sunglasses for women without bifocal aviator',
#  'A bomber jacket with inner warming lining, preferrably black',
#  'front closure strapless bras',
#  'winter car windshield snow cover',
#  'ladies long sleeve tunic tops',
#  '18 quart storage containers',
#  'vetri-liver canine',
#  'dry cracked skin cream',
#  'the rose toy for women',
#  '1.75 leather belts without buckles',
#  'baby magic gift set newborn',
#  'remington curling wand',
#  'shuttle pen retractable',
#  'grinking glasses',
#  'gustus vitae spices',
#  'cat cloud climbing frame cat toy',
#  'cliff kids z bars',
#  'guys workout planner',
#  'porn posters',
#  'sccy cpx-2 holster with red dot',
#  'iphone charger cable',
#  'halloween gift basket',
#  'proform dumbbell set',
#  'milwaukee long screwdriver',
#  'camiseta de los lakers original',
#  '3/8 grosgrain ribbon',
#  'no taste red gel food coloring',
#  'mtm gun case',
#  'coaching clipboard with storage',
#  '1 fl oz hand sanitizer bulk spread love not germa',
#  '#1 best and not expensive bath back brush cream color',
#  'aqua teak',
#  'denim for teens',
#  'ps4',
#  'extra large christmas welcome mat',
#  'fire pit',
#  'dr brown 4oz baby bottles',
#  'black wedding sets for women',
#  'dildo',
#  'boys rash guard short sleeve',
#  'shorts overalls for women loose fit',
#  'navy blue running short',
#  'vongrasig',
#  'moon bounce',
#  'gold decorative wall hooks',
#  'heel o matic roping dummy',
#  'gas can without safety spout',
#  'jets bath tub',
#  'grey bench with storage',
#  'hamilton watches for men',
#  '!qscreen fence without holes',
#  'halo ring set',
#  'salt substitute without potassium',
#  '10 ft rectangular patio hanging umbrella without base',
#  'almond milk without carrageenan',
#  'belt strap without buckle for men',
#  '110 volt heating element without electric cord',
#  'loreal lash paradise mascara',
#  'big wall art canvas',
#  'mens taupe pants',
#  'pint one wheel',
#  '25 lb weights set of 2',
#  'clear storage containers 72 quarts 44x25x12 without lids',
#  'skechers open back shoes for women',
#  'shinker stretcher',
#  'sram battery charger',
#  'halloween decorations',
#  'cd player',
#  'mydmx go',
#  '1 oz plastic shot glasses without lids',
#  'double ended markers not brush',
#  'sauder craft pro series',
#  'corduroy jacket women sherpa',
#  'iphone xs max',
#  'backpack for women',
#  '1 picture frames 16x20 without mat',
#  'dalluge hammer',
#  'outdoor putting green for backyard',
#  "engineer i'm not arguing t shirt",
#  'I want a black leather jacket with gold zips and pocket buttons',
#  'baking vanilla extract',
#  'seasum high waisted leggings',
#  'thomas friends puzzle',
#  'came tv lights',
#  'kids indoor tents',
#  'leather belt without holes',
#  'A long (mid calf length), lightweight beige/brown single breasted trench jacket ',
#  'avon 24 hour on duty deodorant',
#  '1 14 brown leather belt without buckle',
#  "i'm not old i'm a classic",
#  'disney wired ribbon',
#  'fine point pen',
#  'legging shorts high waisted plus size',
#  '10x8 shadow box without glass',
#  'low fat sliced cheese',
#  '10”x14” mirror without frame',
#  'fill in powder with procapil medium brown',
#  'livable sheds for sale',
#  'moscato wine sweet',
#  'black white striped shirt',
#  'batman',
#  'funny baby gifts for parents',
#  'error 404 costume not found',
#  'not my circus not my monkeys t shirt',
#  'buzzaround xl scooter',
#  'small tip paint brushes',
#  'gold and purple throw pillows',
#  'k9 patches with velcro',
#  'juicer',
#  'cat lounger scratcher large',
#  'mini uv light for nails',
#  'snacks',
#  '8.5 x 11 sketchbook hardcover',
#  'kitcen shears',
#  'isopods and springtails live',
#  'single bottle wine chiller',
#  'boyers coffee',
#  'bowling green state university apparel',
#  '250 lb resistance bands for men',
#  'nitrogen base without amino acids',
#  'batman',
#  'fupa shapewear',
#  'wireless headset',
#  'drip hose stakes',
#  '1 1/4 mini metal rustic barn star without hole for the',
#  '013 nail color not gel',
#  'while wheat flour',
#  'things that help pregnancy',
#  'mail key holder wall',
#  'thin mens tshirts',
#  '12x16 shed plans with garage door',
#  'girls backpacks',
#  'drink mix without aspartame',
#  'salt gun',
#  'knit interfacing',
#  'pendaflex heavy duty expanding file with extra-thick cover',
#  'best educational toys for 2 year old',
#  'green christmas wrapping paper',
#  'classic books',
#  'moon bounce',
#  'humidifiers without filters',
#  'evoc multi frame pack',
#  'faux headboard',
#  '. frameless fixed tub door in silver frame without handle',
#  'learning english for kids',
#  'black backpacks for teen girls',
#  'tree without leaves',
#  'cbs products without thc',
#  'extra large under bed storage',
#  'black pastry boxes',
#  'lumpy winnie the pooh stuffed animal',
#  'blue reusable straws',
#  'cat lounger scratcher large',
#  'gsxr levers',
#  'xiao long bao',
#  'loveseat with compartment',
#  'dog automatic water bowl',
#  '000 black jeans not ripped',
#  'zen room decor',
#  'striped tee shirt men long sleeve',
#  'overnight pads for women extra heavy without wings',
#  'womens sweatshirts without hoods',
#  'fall flower pucks',
#  'picture frames',
#  'hollowed out book',
#  'fall decor',
#  'hot pink nike shoes',
#  'dresses for women casual summer',
#  '12 point socket set 1/4 drive metric',
#  '11inch trunks without liner',
#  'aunty tumbler',
#  'gentle cleansing wash',
#  'tru glo night sights',
#  'men top long john',
#  'avocado organic fresh',
#  'bass amp headphones',
#  '10k pearl settings without pearls',
#  '#1 black natural hair dye without ammonia or peroxide',
#  'hakone yosegi',
#  'money machine counter',
#  'vitamin c serum without hyaluronic acid',
#  '3x cotton shirts for men',
#  'grey bench with storage',
#  'bath scrungies',
#  '0.7 mechanical drafting pencil without eraser',
#  "men's shaving razors",
#  'not my circus not my monkeys t-shirt',
#  'kohler greek bathtub',
#  'navy blue rose petals for weddings',
#  'power poles for boats 8ft',
#  'mb series massage chair',
#  '40watt bulb',
#  'cowboy magic shampoo and conditioner for dogs',
#  'flashlight small powerful',
#  'dji drones with camera',
#  'jj suspenders',
#  'front closure strapless bras',
#  '10” disposable dinner plate without small plate',
#  'bath wrap towels for women',
#  'mat man pieces learning without tears',
#  '4 color pens',
#  'apple headphones',
#  'purple dress teen',
#  'red white wired ribbon',
#  'vivekananda books',
#  'vegan collagen powder',
#  'sugar bowl without spoon',
#  '12 x 12 tarp',
#  'xl coffin nail tips',
#  'toothpaste without sweetner',
#  'avalon organics thickening',
#  'face regimen for women',
#  '.75 carat rings band curved',
#  '100% full lace wigs 4/27 without the t part',
#  'tlm103',
#  'small vanity without mirror',
#  'sazon without msg',
#  'wall hooks without nails',
#  'dog beds without stuffing',
#  'womens sweatpants without pockets',
#  'lack fear not beer',
#  'comfy underwear',
#  'boys mini backpack marvel',
#  '100 amp main breaker combination without ring',
#  '10x8 shadow box without glass',
#  'gwent cards',
#  'royal blue sanding sugar edible',
#  'league legacy hat',
#  'dresser',
#  '12 ounce mason jars',
#  'banner supplies',
#  '05 colorado seats not covers',
#  'mini locket charms',
#  'reclining sofa with console',
#  'cruise tote bag',
#  'sports bras for women',
#  'cerave gentle cleanser',
#  'caterpillar boots for women',
#  'orient bambino open heart',
#  'cake revolving stand',
#  'pinball game machine full size',
#  'platform bed without headboard',
#  'gold tennis bracelet set for women',
#  'mask n95 white',
#  'arm and bra fat workout',
#  'houses for kids',
#  'casual shirts for men',
#  'chikko not coffee',
#  'puck lights without remote',
#  'air fryer',
#  'full deep fitted sheet',
#  'women sexual enhancement pills',
#  'men engagement band ring',
#  'acrylic notepad holder',
#  'best card games for families',
#  'legging shorts high waisted plus size',
#  '1 inch long barrel curler without clip',
#  'mini locket charms',
#  '1 inflatable light up pool ball without remote',
#  'croc embossed satchel bag',
#  '0% sad without you tanktop',
#  'dupont tyvek',
#  '20 inch tape in hair extensions human hair',
#  'mop without bucket',
#  ...]

# %%
populate_query('sipsnap', get_search_config(client, 'baseline'))
# Out:
# {'query': {'multi_match': {'query': 'sipsnap',
#    'fields': ['id',
#     'title',
#     'category',
#     'bullets',
#     'description',
#     'attrs.Brand',
#     'attrs.Color']}},
#  'size': 10,
#  '_source': ['title', 'description', 'asin']}

# %%
for query in ubi_user_queries[:10]:
    for id,team in run_AB(client, query, 'baseline', 'baseline with title weight'):
        events = get_events(client, id, query)
        count = events['hits']['total']['value']
        if count:
            print(f"{team} {query}, {id} => {count}")

# %%
for query in ubi_user_queries[:100]:
    for id,team in run_AB(client, query, 'baseline', 'baseline with title weight'):
        count = count_clicks(client, id, query)
        if count:
            print(f"{team} {query}, {id} => {count}")
# Out:
# TeamB resin patio chairs, B06Y4C6ZXZ => 3
# TeamA yeti, B073WJRJZZ => 36
# TeamB red green yellow party decorations, B07R4Y3LXZ => 1

# %%
query_set_df = pd.DataFrame(ubi_user_queries, columns=['query'])
query_set_df
# Out:
#                                        query
# 0     canned tuna solid white albacore water
# 1                  vitamin e oil without soy
# 2                        bikini high waisted
# 3                       budha mural wall art
# 4                      adidas golf shoes men
# ...                                      ...
# 9995                      burn to brown maui
# 9996             dog costumes for large dogs
# 9997                                 mua kit
# 9998                   toronto blue jays cap
# 9999    daddy daughter not always eye to eye
#
# [10000 rows x 1 columns]

# %%
query_set_df['res'] = query_set_df['query'].apply(lambda x: [ (id, count_clicks(client, id, x), team) for id,team in run_AB(client, x, 'baseline', 'baseline with title weight')])
query_set_df = query_set_df.explode('res')

# %%
query_set_df = query_set_df.join(pd.DataFrame(query_set_df['res'].values.tolist(), columns=['id', 'clicks', 'team']))
query_set_df
# Out:
#                                        query                     res  \
# 0     canned tuna solid white albacore water  (B076CQZXXL, 0, TeamB)
# 0     canned tuna solid white albacore water  (B002MDSY56, 0, TeamA)
# 0     canned tuna solid white albacore water  (B08N4TGWXF, 0, TeamB)
# 0     canned tuna solid white albacore water  (B005TOXCX4, 0, TeamB)
# 0     canned tuna solid white albacore water  (B06Y45L4K2, 0, TeamA)
# ...                                      ...                     ...
# 9999    daddy daughter not always eye to eye  (B01FCQUHFY, 0, TeamA)
# 9999    daddy daughter not always eye to eye  (B089YTJRB3, 0, TeamB)
# 9999    daddy daughter not always eye to eye  (B0838J8RQG, 0, TeamA)
# 9999    daddy daughter not always eye to eye  (B07VRSP12M, 0, TeamB)
# 9999    daddy daughter not always eye to eye  (B00XAJI1AE, 0, TeamB)
#
#               id  clicks   team
# 0     B076CQZXXL     0.0  TeamB
# 0     B076CQZXXL     0.0  TeamB
# 0     B076CQZXXL     0.0  TeamB
# 0     B076CQZXXL     0.0  TeamB
# 0     B076CQZXXL     0.0  TeamB
# ...          ...     ...    ...
# 9999  B06XQKQYSB     0.0  TeamA
# 9999  B06XQKQYSB     0.0  TeamA
# 9999  B06XQKQYSB     0.0  TeamA
# 9999  B06XQKQYSB     0.0  TeamA
# 9999  B06XQKQYSB     0.0  TeamA
#
# [97748 rows x 5 columns]

# %%
query_set_df[query_set_df['team'] == 'TeamA'].describe()
# Out:
#              clicks
# count  46872.000000
# mean       0.019201
# std        0.604767
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       36.000000

# %%
query_set_df[query_set_df['team'] == 'TeamB'].describe()
# Out:
#              clicks
# count  50766.000000
# mean       0.013789
# std        0.312274
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       11.000000

# %%
query_set_df[query_set_df['team'] == 'TeamA'][query_set_df[query_set_df['team'] == 'TeamA']['clicks'] > 0]
# Out:
#                     query                     res          id  clicks   team
# 178      echo dot 3rd gen  (B083NTHSJH, 0, TeamA)  B073WJRJZZ    36.0  TeamA
# 178      echo dot 3rd gen  (B08XB3XCQ4, 0, TeamB)  B073WJRJZZ    36.0  TeamA
# 178      echo dot 3rd gen  (B07GPN3MRY, 0, TeamA)  B073WJRJZZ    36.0  TeamA
# 178      echo dot 3rd gen  (B07XDB4Z5Q, 0, TeamB)  B073WJRJZZ    36.0  TeamA
# 178      echo dot 3rd gen  (B07H4ZNHPY, 0, TeamA)  B073WJRJZZ    36.0  TeamA
# ...                   ...                     ...         ...     ...    ...
# 9709  klein cable cutters  (B084P11D8M, 0, TeamA)  B09CR6XHDD     2.0  TeamA
# 9709  klein cable cutters  (B000GASHJU, 0, TeamB)  B09CR6XHDD     2.0  TeamA
# 9709  klein cable cutters  (B071LCCGT1, 0, TeamA)  B09CR6XHDD     2.0  TeamA
# 9709  klein cable cutters  (B083Q8K2N5, 0, TeamA)  B09CR6XHDD     2.0  TeamA
# 9709  klein cable cutters  (B06X9M41M9, 0, TeamB)  B09CR6XHDD     2.0  TeamA
#
# [100 rows x 5 columns]

# %%
query_set_df[query_set_df['team'] == 'TeamB'][query_set_df[query_set_df['team'] == 'TeamB']['clicks'] > 0]
# Out:
#                                   query                     res          id  \
# 160                    thomas the train  (B07J6FDHR9, 0, TeamA)  B06Y4C6ZXZ
# 160                    thomas the train  (B077XKQNG9, 0, TeamB)  B06Y4C6ZXZ
# 160                    thomas the train  (B07T8T45G2, 0, TeamB)  B06Y4C6ZXZ
# 160                    thomas the train  (B01NCZ5PTU, 0, TeamB)  B06Y4C6ZXZ
# 160                    thomas the train  (B000BXJTIK, 0, TeamA)  B06Y4C6ZXZ
# ...                                 ...                     ...         ...
# 9960  ruger american compact 45 holster  (B01EIHELAA, 0, TeamA)  B098X2GWS1
# 9960  ruger american compact 45 holster  (B08943PKSC, 0, TeamA)  B098X2GWS1
# 9960  ruger american compact 45 holster  (B01N0P3Y08, 0, TeamA)  B098X2GWS1
# 9960  ruger american compact 45 holster  (B0764LQJ99, 0, TeamB)  B098X2GWS1
# 9960  ruger american compact 45 holster  (B000RMZSYE, 0, TeamB)  B098X2GWS1
#
#       clicks   team
# 160      3.0  TeamB
# 160      3.0  TeamB
# 160      3.0  TeamB
# 160      3.0  TeamB
# 160      3.0  TeamB
# ...      ...    ...
# 9960     8.0  TeamB
# 9960     8.0  TeamB
# 9960     8.0  TeamB
# 9960     8.0  TeamB
# 9960     8.0  TeamB
#
# [130 rows x 5 columns]

# %%
query_set_df[query_set_df['team'] == 'TeamB'][query_set_df[query_set_df['team'] == 'TeamB']['clicks'] > 0].describe()
# Out:
#            clicks
# count  130.000000
# mean     5.384615
# std      3.038218
# min      1.000000
# 25%      3.000000
# 50%      6.000000
# 75%      7.000000
# max     11.000000

# %%
query_set_df[query_set_df['team'] == 'TeamA'][query_set_df[query_set_df['team'] == 'TeamA']['clicks'] > 0].describe()
# Out:
#            clicks
# count  100.000000
# mean     9.000000
# std      9.566355
# min      2.000000
# 25%      4.000000
# 50%      5.000000
# 75%     10.000000
# max     36.000000

# %%
query_set_df.to_csv('ubi_queries_df_2.csv')

# %%
get_search_config(client, name="baseline with title weight")

# %%
get_search_config(client, name="baseline")
