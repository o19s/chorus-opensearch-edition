# %%
import numpy as np
import pandas as pd
import random
import json
from opensearchpy import OpenSearch
import os
OPENSEARCH_HOST = os.getenv("OPENSEARCH_HOST", "localhost")
OPENSEARCH_PORT = os.getenv("OPENSEARCH_PORT", 9200)

# %%
def interleave(listA, listB, k):
    ids = []
    teams = []
    rank = 1
    idx_a = 0
    idx_b = 0
    len_a = len(listA)
    len_b = len(listB)

    while rank <= k:
        a_val = listA[idx_a]['_id'] if idx_a < len_a else None
        b_val = listB[idx_b]['_id'] if idx_b < len_b else None
        if not (a_val and b_val):
            # lists are done
            return zip(ids, teams)
        if not a_val:
            # take the rest of listB
            for hit in listB[idx_b:k]['_id']:
                if hit not in ids:
                    ids.append(hit)
                    teams.append('TeamB')
            return zip(ids, teams)
        if not b_val:
            # take the rest of listA
            for hit in listA['_id']:
                if hit not in ids:
                    ids.append(hit)
                    teams.append('TeamB')
            return zip(ids, teams)
        a_first = idx_a < idx_b or idx_a == idx_b and random.randint(0,1)
        if a_first:
            if a_val not in ids:
                ids.append(a_val)
                teams.append('TeamA')
                rank += 1
            idx_a += 1
        else:
            if b_val not in ids:
                ids.append(b_val)
                teams.append('TeamB')
                rank += 1
            idx_b += 1       
    return list(zip(ids, teams))


def get_list(listA, listB, k):
    A = listA['hits']['hits']
    B = listB['hits']['hits']
    interleaving = interleave(A, B, k)
    return interleaving

def get_search_config(client, name):
    search_configs_index = 'search-relevance-search-config'
    conf = client.search( body = {
      "query": {
        "match": {"name": name}
      },
      "size": 1
    }, index=search_configs_index)
    return conf['hits']['hits'][0]['_source'] if len(conf['hits']['hits']) else {}

def populate_query(query, config, size=10, source=["title", "description", "asin"]):
    query = query.replace('"', '\\"')
    body = json.loads(config['query'].replace("%SearchText%", query))
    body['size'] = size
    body['_source'] = source
    return body

def run_AB(client, query, configA, configB, size=10):
    confA = get_search_config(client, configA)
    confB = get_search_config(client, configB)
    qA = populate_query(query, confA, size=size)
    qB = populate_query(query, confB, size=size)
    #TODO: extract the endpoint value from the search config, rather than using the client here
    resA = client.search(body=qA)
    resB = client.search(body=qB)
    result = get_list(resA, resB, 10)
    return result

# This will conflate different query-ids in ubi events. Needs review
def get_events(client, id, query, event_type=None):
    if event_type:
        evq = {
          "query": {
            "bool": {
             "must": [   
                 {"match": {"event_attributes.object.object_id": id}},
                 {"match": {"user_query": query}},
                 {"match": {"action_name": event_type}}
             ]
            }
          },
          "size": 1000
        }
    else:
        evq = {
          "query": {
            "bool": {
             "must": [   
                 {"match": {"event_attributes.object.object_id": id}},
                 {"match": {"user_query": query}}
             ]
            }
          },
          "size": 1000
        }
    results = client.search(body=evq, index='ubi_events')
    return results

def get_clicks(client, id, query):
    results = get_events(client, id, query, 'click')
    return results

def count_clicks(client, id, query):
    results = get_clicks(client, id, query)
    return results['hits']['total']['value']

# %%
# Create the client with SSL/TLS and hostname verification disabled.
client = OpenSearch(
    hosts = [{'host': OPENSEARCH_HOST, 'port': OPENSEARCH_PORT}],
    http_compress = True, # enables gzip compression for request bodies
    use_ssl = False,
    verify_certs = False,
    ssl_assert_hostname = False,
    ssl_show_warn = False
)

# %%
ubi_queries = client.search(body={'query': {'match_all': {}}, "size":10000}, index='ubi_queries')
ubi_user_queries = [x['_source']['user_query'] for x in ubi_queries['hits']['hits']]
ubi_user_queries
# Out:
# ['A long (mid calf length), lightweight beige/brown single breasted trench jacket ',
#  'iwo jima statue',
#  'diamond band rings for women size 4',
#  'hair dryer',
#  'cursive kickoff handwriting without tears',
#  'tiered spice rack organizer',
#  'robot vacuum',
#  'jeansian shirts for men',
#  'yoga outfits for women 2 piece set high waist',
#  'gaming chair',
#  'mattress queen',
#  'truck roof tent',
#  'unscented toilet paper',
#  'align tank top dupes lululemon',
#  'cbd oil not hemp oil',
#  'my life would suck without you',
#  'heated floor thermostat',
#  'chilli seasoning packets',
#  'liquid probiotic for women',
#  'work will suck without you water bottle',
#  'apple airpods',
#  'toiletries travel bag men',
#  'maxpider tesla model y',
#  'halo',
#  '10 pocket folders without brads',
#  '110v led strip lights',
#  'kids farm boots for girls',
#  'juicy toddler girl',
#  'tan towel set',
#  'delish white jordan almonds',
#  '1 1/2 black drain without overflow',
#  'walnut knife block without knives',
#  'seat cushion not memory foam',
#  "i'm pregnant not a petting zoo",
#  'biomemd probiotic and prebiotic for women',
#  'backpack',
#  'kit homes prefabricated',
#  'queen bed frame',
#  'haus heavy duty',
#  'body wave headband wig',
#  'jump rope without the rope',
#  'pot with strainer lid',
#  '4xl funny tshirts for men',
#  '1 weight bar without weights 7ft',
#  'tumi wallets',
#  '3t romper boys',
#  '1/2 eye frames without glass',
#  'stand white board',
#  'tactical sunglasses for men military polarized',
#  'cocokind chlorophyll mask',
#  'grey kitchen table',
#  'athletic greens powder',
#  'candylips mini plumper',
#  'buffalo plaid',
#  'best hair scissors professional',
#  'dji enterprise advanced',
#  'it cc cream',
#  'dealcoholized wine',
#  'silver and white wall decor',
#  'pocket t shirts for men big and tall',
#  'harley touring p clamp black gloss',
#  'crayola gobbles 1 pack',
#  'amazon gift card',
#  'california sweatshirt for women',
#  'lidded ice cube trays',
#  't towels kitchen',
#  'snort pines not lines',
#  '1/2 inch avery binder',
#  'pantry bins stackable',
#  'asics pickleball shoes men',
#  'k9 carrier',
#  'dog bath tub and wash station',
#  'cdb oil for pain and anxiety',
#  'carpio wrist rest',
#  'cork and white board combo',
#  'casual simple dresses for women',
#  'japan deep frying pan',
#  'shower mixing valve kit',
#  'costa sunglasses for women',
#  'drone yuneec',
#  '14k rose gold earrings',
#  'salas para casa sofas baratos',
#  '1oz glass spray bottles',
#  'candylips mini plumper',
#  'mug without handle',
#  'office name plates for desks',
#  'you are the monica to my rachel mug',
#  '3m bayonet filter',
#  '#10 window envelopes without plastic',
#  'firestick',
#  'dog rawhide bones',
#  'black office desk',
#  'boflex weight',
#  'knot sealer for lace wigs',
#  '12 speed groupset',
#  'shinker stretcher',
#  'snort pines not lines',
#  'rechargeable batteries',
#  'sauder craft pro series',
#  'tiny wreaths for crafting',
#  'chevrolet wall clock',
#  'throw pillows',
#  'flocked wreaths',
#  'sparkly 2 piece outfits for women sexy',
#  'iphone x case',
#  'mesh bag for washing shoes',
#  'bath and body works',
#  'glass old fashioned',
#  'mail key holder wall',
#  'green and white striped shirt',
#  'lynn austin books',
#  '1 wine glasses without stems',
#  'tiger stuffed animal',
#  'throne chairs for party cheap',
#  'coodenkey',
#  'sparkling cider mini bottles',
#  'gender not found',
#  'burn stomach fat for women',
#  'white slim christmas tree with lights',
#  'clairol purple shampoo for blonde hair',
#  'different not less shirt',
#  'k necklace gold',
#  'chicken wrap dog treats',
#  'mirror bathroom wall',
#  '22 heavy duty cotton canvas tote bag zippered',
#  'retirement gift',
#  'raid deep reach fogger',
#  'im608 pro',
#  '105 cm belt strap without buckle',
#  'dildos',
#  'drinks without sugar',
#  'white stuffed animal',
#  'mens pants',
#  'iphone 8 plus',
#  'wink white lotion',
#  'front closure strapless bras',
#  'latin dance shoes',
#  'smart cutter as seen on tv',
#  'baby wipes',
#  'toddler knee socks',
#  '#2 dixon oriole pencils not sharpened',
#  'pocket planner without dates',
#  'venus fly trap terrarium',
#  'hot pink nike shoes',
#  'cable exercise equipment',
#  'densurefit denture reline kit',
#  'yoga mat black and white',
#  'womens black high waisted bikini bottoms',
#  'tob womens sexy criss cross',
#  'replacement brush heads sonicare',
#  'create 365 planner mini accessories',
#  '1.25 drain popper without overflow',
#  'pink jump rope for women',
#  '1.25 gallon buckets without lids',
#  'vibrant jeans for girls',
#  'i love new york socks',
#  'watch ya mouth game',
#  'cbs products without thc',
#  'computer monitor',
#  'l.o.l. surprise! winter disco cottage playhouse',
#  'catnip free cat toys',
#  'oil rubbed floor register',
#  'air freshener',
#  'aveeno nourishing cleanser',
#  'medical gauze',
#  'chicken wrap dog treats',
#  'fire pit',
#  'yahama bass guitar',
#  'dewalt 745 table saw',
#  'magnified lighted mirror',
#  'daily planner without dates',
#  '85 th birthday decorations',
#  'omega 3 without fish oil',
#  'dishwasher safe knife set without block',
#  'smartstraps bungee cords',
#  'antiseptic wipes individually wrapped',
#  'manual tapping machine',
#  'coffee maker',
#  'foam mattress twin',
#  'dead foot skin',
#  'vsco stickers',
#  'xl full body harness',
#  'bodenov mask',
#  'shark hot wheels monster truck',
#  'miami cuban chain',
#  'depends night defense medium for women',
#  '$12 label maker that’s not a cheap one',
#  'cigarette case with lighter',
#  '1/2 eye frames without glass',
#  'glow sticks party pack',
#  '13mwz wrangler cowboy cut original fit jean',
#  'dual magnetic eyelashes without eyeliner',
#  'hang clothes without closet',
#  'xl tall moisture wicking shirt',
#  'rug deep cleaner',
#  'corksickle coffee tumbler',
#  'teen small breathable face mask',
#  'l cetrulline',
#  'emirates toy plane',
#  'plug in string lights',
#  'sala set sofa',
#  'mens jackets casual with hood',
#  'woke up sexy as hell again tshirt',
#  'the dude big lebowski',
#  '.4 mm not bleed pen',
#  '120ft led light',
#  'sloth not today',
#  'merlin magic sleepsuit large',
#  'welder nation welding caps',
#  'gm running boards',
#  'biomemd probiotic and prebiotic for women',
#  'lego city',
#  'grass for walls',
#  'pink kid watch girl',
#  'large rabbit hutch',
#  'dogs potty grass',
#  'work hard stay humble shirt',
#  'iv needles',
#  'create 365 planner mini accessories',
#  'cats make me happy you not so much',
#  'yonex mavis 500',
#  'organic coconut water not from concentrate',
#  '8 inch memory foam mattress full',
#  'light blue christmas tree',
#  'gel padded bike shorts for men',
#  'no tip dog bowl ceramic',
#  'tiny cars for boys',
#  'beauty without cruelty',
#  'gold decorative wall hooks',
#  'empty roller bottles',
#  'coccyx pain relief products',
#  'gold stud 1.5',
#  'rustic ceiling fan without light',
#  'wood equipment tools',
#  'fuji white paint',
#  'tuningpros',
#  'psychadelic tapastry',
#  'boxes for moving medium and large',
#  'baby boy and girl matching outfits',
#  'imperatorworks',
#  'solaray mega multi mineral without iron',
#  'bike key holder',
#  'plain plastic headbands',
#  'boys mini backpack marvel',
#  'xl coffin nail tips',
#  'dumbbell set with rack 5-50 lbs',
#  'andis outliner',
#  '07 cadillac escalade headlights without ballest',
#  'straight teeth without braces',
#  'shovels for kids',
#  'pencil case',
#  'pearl and diamond earrings',
#  'k9 patches with velcro',
#  '1/2 soaker hose without ends',
#  'educational toys for 6 year olds',
#  'here for a good time not a long',
#  'tea cup infuser set',
#  'tinted moisturizer without spf',
#  'kitchen toys set for kids',
#  'big and tall button down shirts',
#  'injury ice pack long lasting',
#  'boom golf bag',
#  'thorne basic nutrients v without iron and iodine',
#  'active man multivitamin',
#  'space base board game',
#  'kayak',
#  'personal lift for elderly',
#  'replicade insert coin keychain',
#  '3 x 1 box',
#  'multiprocess welder',
#  'kanoodle puzzle game',
#  'x light',
#  'tub faucet without diverter',
#  "men's spf swim shirts",
#  'rick and morty tray',
#  'hideaway led strobe lights',
#  'mice proofing',
#  '32 degrees jackets for women',
#  '100xx tanning lotion without bronzer for tanning beds',
#  'dr plotka toothbrush',
#  '3m automotive painting tape',
#  'vibrators',
#  '1/2 soaker hose without ends',
#  'crepe paper purple',
#  'white dresses for women',
#  'gifts for godparent',
#  'leather belt without holes',
#  'cropped turtleneck women',
#  'cute womens tops',
#  '80 x 32 inch barn door',
#  'catnip free cat toys',
#  'cricut',
#  'jeans american eagle for men',
#  'iphone 7 plus case',
#  'coq10 without soy',
#  'atainless steel straws',
#  'yes charcoal stick',
#  'no u card game',
#  'bee traps outdoor hanging',
#  'colored wedding bands',
#  'kids nutritional shake',
#  'toys for 11 year old boys best sellers',
#  '110cfm bathroom exhaust fan without light',
#  'cow shirt',
#  'office chair',
#  "'m not sleeping i'm just resting my eyes shirt",
#  'backpacks',
#  'hydromate motivational bottle with straw',
#  'grey curtains',
#  'closet freshener long lasting',
#  'ao smith water tank',
#  'the future is female shirt',
#  'outdoor carts for patio',
#  '10 gage electrical wire without ground',
#  'girdle for women tummy control',
#  'dulcolax liquid laxative',
#  'computer desk for small spaces',
#  'ling ling potstickers',
#  'air freshener',
#  'techware pro ankle brace',
#  'ortur',
#  'womens red zip up hoodie',
#  'chair',
#  'luggage',
#  'trowel machine 36 inch',
#  'large welcome mats for front door outdoor',
#  'grateful im not dead',
#  'popup sink drain without overflow',
#  'baby wipes',
#  'multivitamin without vitamin k',
#  'anime makes me happy you not so much',
#  'frye key fob',
#  'gallon reusable ziploc bags silicone',
#  'centering prayer',
#  'bathtub mats without suction cups',
#  'yoga outfits for women 2 piece set high waist',
#  'jeansian shirts for men',
#  'small desk',
#  'apple airpods',
#  'pecan coffee ground',
#  'coconut extract pure for baking',
#  'diapers chlorine free',
#  'back off i have a sister and im not afraid to use her',
#  'privacy window film see out not in',
#  'eye drops without preservatives',
#  '110 outlet for use without box',
#  'reecho hair extensions',
#  'rugs brown and beige',
#  'bosch 10 inch table saw',
#  'rado watches for men',
#  'glass skull drink dispenser',
#  'to fish or not fish',
#  'plaid trousers for women',
#  'skinny jeans for boys',
#  'flat tummy cream for women',
#  'whole salt and pepper for grinder',
#  'spreads for sandwiches',
#  'fruitcakes with rum or brandy',
#  'boat throw blanket',
#  'just one you bibs',
#  'active man multivitamin',
#  'black fan without light',
#  'sports water system',
#  '1 large white silk gardenia without stem',
#  '$10 magnetic eyelashes without eyeliner',
#  'twin mattress',
#  'play room wall decals',
#  'led lights for bedroom without plug in',
#  'propane portable shower',
#  'hitachi massage wand original',
#  'balega running socks women',
#  'make art not war',
#  'pool pressure meter',
#  'sand socks kids',
#  'throw pillows without covers',
#  '10” glass japanese floating glass without netting balls',
#  'orazio 60 pairs stud earrings',
#  'ast enzymes',
#  'scentair scentwave',
#  'halloween costumes for women',
#  'glass old fashioned',
#  'ponds bb cream',
#  'even a global pandemic could not stop me graduation',
#  'tea with probiotics',
#  '1 set plastic 5 tab dividers without pockets',
#  'showtime',
#  'ninebot go kart pro',
#  'do or do not there is no try vinyl',
#  'girls tap shoes size 12',
#  'bodycon shorts for women',
#  'recessed box without flange',
#  'versace dreamer for men',
#  'rolex watches women datejust gold',
#  'iphone 8 case',
#  '234 torsion spring',
#  'men belts without buckles',
#  'mens slim bootcut jeans',
#  'earth not a globe',
#  'blue and brown wall decor',
#  'vinpositine',
#  'mens khaki shorts big and tall',
#  'red glow powder',
#  'compression socks women',
#  'bounty essentials paper towel',
#  'gucci crossbody bags',
#  'best orbital polisher buffer',
#  'mauve lipstick matte long lasting',
#  'rc drone without camera',
#  'dresses for women casual summer',
#  'toys for under 10 dollars',
#  'random room decor for teen girls',
#  '5 piece wall art',
#  'dji zoom 2',
#  'resistance bands',
#  'lapdesk',
#  'cricut',
#  'off white queen bed skirt 16 inch drop',
#  'wood decorative cutting board',
#  'things to get teens for christmas',
#  'tape and mudding tools',
#  'whole nature whole food multivitamin',
#  'clairol purple shampoo for blonde hair',
#  'blank nyc jacket',
#  'round baking pans',
#  'fender deluxe reverb',
#  'fortnight socks do not disturb',
#  'jerky without sugar',
#  'pro stretcher foot rocker',
#  '07 cadillac escalade headlights without ballest',
#  'honeybush tea bags',
#  'bulk babys breath',
#  'yoga tanks tops',
#  'baby water without fluoride',
#  'boho white throw pillows',
#  '4 pack ping pong paddles',
#  'couvre dark brown',
#  'large welcome mats for front door outdoor',
#  'st teresa of avila',
#  'mens shorts',
#  'fed not fed sign for pets',
#  'afo brace right foot',
#  '#pinkandproud not sorry glitter lipstick',
#  'hand cleaner without pumice',
#  'compressor hose reel without hose',
#  'black knife block without knives',
#  'illumibowl toilet night light',
#  'coast soap bars original',
#  "''i am here for a good time not a log time'' sticker",
#  'aqua teak',
#  'black and white air max shoes for women',
#  'air fryer',
#  'ddj sx3',
#  'baby wipes',
#  'ponds bb cream',
#  'pill gun for small dogs',
#  'cafe racer seat',
#  'zaterans seasoning',
#  'shaker bottle',
#  '6 month pajamas boy',
#  '110 volt heating element without electric cord',
#  'woods decorations for home',
#  'ps4',
#  'wedding dress without train',
#  'wool lite for sweaters',
#  'supreme',
#  'angel isabella, llc',
#  'gloves',
#  'maternity bodycon maxi dress',
#  'bee traps outdoor hanging',
#  'gold pearl necklace',
#  'night air fragrance oil',
#  'chlorophyll without parabens',
#  'hair color without harsh chemicals',
#  'drugs not hugs',
#  'berbertine',
#  'catnoir toy',
#  'ducted dehumidifier',
#  'arab jewelry for women',
#  'empty roller bottles',
#  'claires solution',
#  'phion balance',
#  'brown tights for women',
#  'migraine relief without caffeine',
#  'rivet planter',
#  'fear factor games',
#  'ja morant jersey',
#  'nato watch straps',
#  'no shock dog collar with remote',
#  'suitcase',
#  'free',
#  'winter skirts for women',
#  'byredo hair perfume',
#  'butt workout machine',
#  "'forget me not i' 2 piece framed print",
#  'birthday stuff for teen girls',
#  '1/8 inch microphone windscreen',
#  'book bags classroom set',
#  'macbook air',
#  'chips',
#  'gifts',
#  'queen bed with led lights and nightstand',
#  'pitsburge steelers mask',
#  'oil rubbed floor register',
#  '580 rack',
#  'kids firefighter hat',
#  'charred white oak barrel',
#  'k9 patches with velcro',
#  '32 d bras for women',
#  'lego star wars',
#  'casual tops for women plus size 3/4 sleeve',
#  '8ft pool tables for adults',
#  'we’re not really strangers game',
#  'water transfer paper',
#  'die with memories not dreams shirt',
#  'macha green tea powder organic',
#  'dupont tyvek',
#  'ravens wall decor',
#  'floral baseball tee',
#  '#3 metal zipper slider not made in america',
#  'engagement rings for women black diamond pear shape',
#  '32 degrees jackets for women',
#  'x-plus biollante',
#  'sexy valentines day gifts for him',
#  'photo metal prints',
#  '0.5 aluminum tin without lids for candles',
#  '1/2 inch curling iron for hair',
#  'go kart pro ninebot',
#  '.baby girl tshirt with they did not social distance',
#  'the one for whom food is not enough by amanda gorman',
#  'gun holsters, cases & bags',
#  'boys rash guard short sleeve',
#  'tsm gaming chair',
#  'cloak without hood',
#  'diamond post earrings',
#  'floor sanders for wood floor refinish',
#  'puzzle',
#  'glass jars large with lids',
#  '3x polo shirts for men big and tall',
#  'beauty products for women',
#  'sojag gazebos',
#  'std testing kit for women',
#  'sealed plastic bags for food',
#  'chairs for bedroom',
#  'grapes green seedless',
#  'pet face shield',
#  'kong dog toys for aggressive chewers',
#  'eva nyc mane magic 10-in-1 primer',
#  '30 amp to 20 amp rv adapter',
#  'adult red riding hood costume',
#  'tomy big farm',
#  'matching family christmas pajamas',
#  'key without touching',
#  'blue toilet bowl cleaner',
#  'gold ring for wedding',
#  'super bright white led strips',
#  'keto snacks',
#  'gifts for women',
#  'wwe classic superstars',
#  '16 oz hot cups without lids',
#  'light bulb without blue',
#  '10 x 5 x 13 inch polka dot party bags without handles',
#  'adult cat coloring books',
#  'minute maid pink lemonade',
#  'small boys underwear',
#  '26 toner',
#  'house spray scent long lasting',
#  "truly's",
#  'mom wine glass funny',
#  'aiyuan',
#  'monomer without mma',
#  'drawing tablet',
#  'aj1 black and white',
#  '11inch trunks without liner',
#  'alvin drafting pencil',
#  'black and grey wall art',
#  'quad nerf bars',
#  'cocktail cherries old fashioned',
#  'corn flavored chips',
#  'disposable cocktail glasses for parties',
#  'royal canin labrador retriever',
#  'artificial christmas trees without lights',
#  'kaweco sketch up pencil',
#  'mario kart',
#  '10$ gift card',
#  'projector',
#  'a massage chair',
#  'alvin drafting pencil',
#  'light switch without wiring',
#  'it okay not to be okay braclet',
#  'columbia long sleeve shirts for men',
#  'spring scissors for kids',
#  'lucinda s kitchen',
#  'dyson sv03 battery replacement',
#  'apple watch series 4',
#  'face shield without glasses',
#  't-shirts for men',
#  'corning ware lids french white',
#  'emirates toy plane',
#  'mercer culinary millennia 10-inch wide bread knife',
#  'yoga mat',
#  'home gym 200lb stack',
#  'twin xl comforter sets for college girls',
#  'women diamond rings 14k',
#  'birthday postcards for students',
#  'beville espresso maker',
#  'cve28dp3nd1',
#  'gunpla file set',
#  'gummy krabby patties',
#  'digital camera',
#  'tub faucet without diverter',
#  'jeris hair tonic without oil',
#  'best card games for families',
#  'libbey nob hill',
#  'airpods',
#  'cats make me happy, you not so much',
#  'dog automatic feeder',
#  'fish feeders for aquariums',
#  'futon',
#  'face firming and tightening cream',
#  'lemon yellow blouse',
#  '10 drawer storage cart for a classroom without handles',
#  'electric guitar without amp',
#  '.32 oz vaniply without sunscreen',
#  'boxed wine gifts',
#  'black 5x7 frame',
#  "women's espadrille shoes",
#  'retro green throw pillows',
#  '24 volt pure sine wave inverter',
#  '24 piece cardboard puzzles',
#  'portable white noise machine baby',
#  'gshock solar mens watch',
#  '75 carat diamond rings',
#  '10s unit muscle stimulator without cords',
#  'dressmakers scissors',
#  'slimfast meal replacement bar',
#  'fee brothers peach bitters',
#  '10 exercise ball',
#  'iphone 6 case',
#  'commercial 110 pint dehumidifier',
#  'omega 3 without fish oil',
#  'triple push pop',
#  'deep v lingerie bodysuit',
#  'maybelline coverstick concealer deep beige',
#  "3'x5' rugs",
#  '1/2 inch avery binder',
#  'awesome friend gifts',
#  'amazon diamond rings for women',
#  'tactical sunglasses for men military polarized',
#  'wall hangers without nails pictures',
#  'hang pictures on wall without nails',
#  'gwent cards',
#  'ninebot go kart pro',
#  'high school english',
#  'seeds arugula',
#  'rolex sea dweller',
#  'iphone 8 case',
#  "'you're not 40' - funny birthday card",
#  'anal trainer',
#  'fire tv',
#  'king size bed spreads not comforters',
#  'dadorlian shirt',
#  'marvel against humanity game',
#  'fake 20 dollar bills',
#  'gold bars .999 pure 1 oz real',
#  '035 super clamp without stud, includes 035wdg wedge',
#  'personal wand massager for women',
#  '0.07 lash extensions not easy fans',
#  '1/2 shank router bit without bearing',
#  'sram battery charger',
#  'aunty tumbler',
#  'obd2 scanner tool',
#  'spark plugs gap tool',
#  'enzymatic cleaner for dog urine',
#  'spreads for sandwiches',
#  '10 year out belt without buckle',
#  '0rgans only not piano for sale',
#  'wood boiler water treatment',
#  'acrylic coaster holders without coasters',
#  'oval diamond ring',
#  'razor mx650 dirt bike',
#  'facecream women day',
#  'acrylic paint brush case without brushes',
#  'mask led therapy',
#  'prenatal with probiotic',
#  'signature design by ashley outdoor furniture',
#  'thermometer',
#  'loreal lash paradise mascara',
#  'tool chests with wheels and drawers',
#  '20 by 30 by 1 air filter',
#  'wind up clocks without battery',
#  'dc high tops women',
#  "pautzke's",
#  'best coffee mugs for men',
#  '5mm christmas lights',
#  'louis vutton wallet',
#  'digital alarm clock with usb port',
#  '02cool water bottle mist and sip without lid purple',
#  '16 inch deep pocket full fitted sheet',
#  '3/0 live bait hooks',
#  'all superhero lego sets',
#  'cookies without palm oil',
#  'chevrolet camaro accessories',
#  '12v blue led strip',
#  'bole salts',
#  '1 ounce containers with lids not plastic',
#  'red white pocket square',
#  'decorative pillow',
#  'zxi 900',
#  'desk chair without wheels cheap',
#  'bag insert with cup holder',
#  'baby items for newborns boys',
#  'formal shoes for men without lace',
#  'twin xl white duvet set',
#  '3 piece bridal ring sets vintage',
#  'dutch processes cocoa powder',
#  'easy shaper exercise bar',
#  'pink two piece outfits for women sexy',
#  'mens khaki shorts big and tall',
#  '0-3 months boy sleepers without feet',
#  'grizzly wintergreen long cut',
#  'sa sun hat',
#  'the old that is strong does not wither patch',
#  'dishwasher safe knife set without block',
#  'proform dumbbell set',
#  'lego halo hunter',
#  'remington curling wand',
#  'yeti for kids',
#  'ufo led high bay light',
#  'removal tools',
#  'womens mad hatter costume black and white',
#  'go bowen electric kids go kart',
#  'calcium supplement without d',
#  'aqualogix bells',
#  'workout tops for women',
#  'pure monk fruit sweetener without additives',
#  'natural path silver wings',
#  'great white mycorrhizae',
#  'party games for families',
#  'ceramic tiles for crafts',
#  'educational toys for 6 year olds',
#  '14 year old girl gifts',
#  'tulip slick paint',
#  'vaisala hm70',
#  'kids roping rope',
#  'kids raincoat boys',
#  'sparklers candles for cake',
#  'men long sleeve polo shirts',
#  '4x6 farmhouse picture frame',
#  'stickles glitter glue',
#  'baby girls long sleeve flowers hoodie',
#  'yugi cards deck',
#  'unique house gifts',
#  'disposable cocktail glasses for parties',
#  'sewing basket without accessories',
#  'luggage sets samsonite',
#  'baby boy gifts newborn unique',
#  'incredibles costume adult',
#  'light blue intense dolce and gabbana women',
#  "boys' bracelets",
#  'floral wallpaper stick and peel',
#  'mattress without springs',
#  'skinny black ripped jeans men',
#  'iv nail lamp kit',
#  'enfamil polyvisol without iron',
#  'dewalt tool cases without tools',
#  'papasan outdoor chair cushion',
#  'milwaukee tools',
#  'white fold dianobd earribgs screw bacj',
#  'toy bin organizer kids',
#  'coffee maker',
#  'vintage peg votive candle holders',
#  'kiwi bird stuffed animal',
#  'chromebook',
#  'sweat pants outfits for women loose fit plus size',
#  '$230 pool for outdoors not plastic',
#  'ripped jeans women high waisted',
#  'natural braided hairstyles without weave for black women',
#  'extra large lazy susan turntable 40 inch',
#  'yarn green christmas',
#  'honeycomb shelves for wall',
#  'cat cloud climbing frame cat toy',
#  'knit blanket with tassels',
#  'I would be looking for a laptop that is good value and lightweight with long battery life.',
#  'es shoes skateboard',
#  'byrokko shine brown tanning cream',
#  'yamaha hs5 active studio monitor',
#  'lenovo laptop',
#  'best building toys for 4 year old',
#  'russbe reusable bags',
#  'bifocal sunglasses for women',
#  '013 nail color not gel',
#  'better not younger lift me up hair thickener',
#  'halo newborn insert',
#  'fgci deep pour epoxy resin',
#  'gnosis',
#  'i do not spew profanities mug',
#  'bandages flexible fabric',
#  'all black yankees hat',
#  'clothes for men levis',
#  'thin mens tshirts',
#  '1 pocket folder without prongs',
#  'economy 3 ring binder',
#  '4t socks girls',
#  '$175 gram led frisbee gram not dollar',
#  'red and black hanging decorations',
#  'midliner brush pens',
#  'window fans twin reversible quiet with remote',
#  'gun backpack for men',
#  'amusement park lego set',
#  'mary kay desmaquillante',
#  'lol dance dance dance doll omg',
#  'baby blue throw pillows',
#  'party dress for women sexy elegant',
#  '5 string bass guitar',
#  'little people toys',
#  'smuckers peanut butter',
#  'tannerite gender reveal powder kit',
#  'pinty scope',
#  'led lights',
#  'pool floats',
#  'water flavoring packets without aspartame',
#  'remote control car',
#  'hitachi magic wand with speed controller',
#  'tribesigns white bookshelf',
#  '3 candle holder centerpiece',
#  'misumi acne',
#  'led cigarette lighter light',
#  'hanging supplies without nails',
#  'pillow too mattress pad',
#  'black lol dolls for girls',
#  'samsung s9',
#  'candle jars without lids',
#  'chrome hand towel hooks for bathrooms',
#  'em sculpting machine professional',
#  'mens xxl compression socks',
#  'knitting yarn organizer',
#  '1 set plastic 5 tab dividers without pockets',
#  'womens adidas shoes',
#  '12 inch metal straw',
#  'gel pads for high heels',
#  'baby proof cabinets without drilling',
#  'keep grinding hat',
#  '1-3/8 inch door bottom without drip cap',
#  'm salt michigan',
#  'kohler wall hung toilet',
#  'plant stand',
#  'bulk large garbage bags',
#  'bath mat without suction cups',
#  'vanity fair panties illumination',
#  'storage cubes',
#  '12x10 gazebo',
#  'reusable camping trash bag',
#  'eye supplements for dogs',
#  'bose karaoke system',
#  'tool chests with wheels and drawers',
#  'diy wig making kit',
#  'glass skull drink dispenser',
#  'matrix high amplify shampoo',
#  'modern mid century chair',
#  'air force shirt',
#  'brown party decorations',
#  'extra large dish drainer and tray',
#  '10” platform bed without headboard',
#  'nudie posters sexy uncensored',
#  'no chip clear nail polish top coat',
#  'pink kid watch girl',
#  'super dark self tanner',
#  'roses without chemicals',
#  'kaoyoo',
#  '2 ct diamond earrings',
#  'vizzy hard seltzer',
#  'natural path silver wings',
#  'gift cards for amazon',
#  'black teddy jacket',
#  'cartier watches for men',
#  'canvas hammock without stand',
#  'gulf breeze white cover up',
#  'logitech',
#  'timberland boots for women',
#  'boco gear face mask',
#  'milling vise',
#  '11 diameter planter pot without drainage hole',
#  'gatorade',
#  'kp lotion',
#  'A short length light blue denim jacket which looks faded or worn',
#  'iwatch',
#  'leg press machines for home use',
#  'go-cart',
#  'disposable aluminum pans without lids',
#  'magswitch',
#  'artificial tears without preservatives',
#  'black aprons for adults with pockets',
#  'spray bottle',
#  'ventaire baby bottles',
#  'shampoo without water',
#  'pink bling decal',
#  'hybrid queen mattress 12 inch',
#  'extra high waisted shorts for women',
#  'oil diffuser without light',
#  'navy earrings',
#  'fanny pack',
#  'bookends decorative unique',
#  'we’re not really strangers game',
#  'speedo black one piece swimsuits for women',
#  'led mini christmas lights',
#  'cali king duvet cover',
#  'leupold fixed power scope',
#  '1.25 gallon buckets without lids',
#  'cubavera mens shirts big and tall',
#  'pencil case',
#  'lori wall bed',
#  '10 open window envelopes without plastic window',
#  'long leg boxer briefs for men',
#  'thin mens tshirts',
#  'shopkins mini brands',
#  'reef phantom flip flops men',
#  'behritone',
#  'avengers endgame',
#  'seiko sportura watches for men',
#  'lindt white chocolate',
#  '11/4 leather belt without buckle',
#  '1 gpm propane water heater not adapter',
#  'orazio 60 pairs stud earrings',
#  'adult cat coloring books',
#  'panda crate toys 0-24',
#  '6-24x50 rifle scope vortex',
#  'leupold scout scope',
#  'coffee filters',
#  'funny adult valentines day cards',
#  'you may not know me but i got your 6 shirt',
#  'ez carafe',
#  'better homes & gardens pergola',
#  '16mm pink glass beads',
#  'tombow white out tape',
#  'corner desk',
#  'airpods 2',
#  'iphone 8 plus case',
#  'desk chair without wheels cheap',
#  'dc high tops women',
#  'love is not cancelled',
#  '11inch trunks without liner',
#  'teton hydration backpack',
#  '.5 cc syringe without needle',
#  'flip art kit',
#  'kayak hooks for garage',
#  'midas m32r',
#  'bmi scales digital weight and body fat',
#  'wall dividers for rooms cheap',
#  'casio illuminator watches for men',
#  'toddler girls cotton short sleeve casual dresses',
#  'iphone',
#  'loveseat with compartment',
#  'lamp base only without shade',
#  'fish feeders for aquariums',
#  "100' hose without fittings",
#  'black teddy jacket',
#  'copper glasses water',
#  'knit interfacing',
#  'new balance mens shoes',
#  'puma pounce low cut socks',
#  'patio umbrella',
#  'razors without lubricating strip',
#  'cow shirt',
#  'badges without borders',
#  ', rotating extended fans not a ceiling fan',
#  'paisley blouses for women',
#  'spray bottle',
#  'where the crawdads sing',
#  'star wars',
#  'vibrant jeans for girls',
#  'aquarium',
#  '1-14” coco wire plant holder without basket',
#  '2 ply paper napkin',
#  'cousin shirts for kids',
#  'dog toy without squeaker',
#  'fairy decorations',
#  '1 gal. steel paint cans without lids',
#  'simply organic all-purpose seasoning 2.08 oz',
#  'warm white christmas lights',
#  'ullo wine filters',
#  'centering prayer',
#  '44 inch ceiling fan without light',
#  'sugar tester diabetes kit without needle',
#  'seal pour food storage bag clip',
#  'diamond band rings for women size 4',
#  'organic beeswax food wraps',
#  'pills that make you not hungry',
#  'mattress topper',
#  'porch lock box for packages',
#  'forgrip',
#  'boho tree topper',
#  'cute pajamas for teen girls',
#  'merlin magic sleepsuit large',
#  'boys yellow under armour shirt',
#  'girls invented punk rock not england shirt',
#  'cheer leader costume for women',
#  '10x8 shadow box without glass',
#  'majoras mask mask',
#  'sofa',
#  "'love not perfect inspirational family' canvas",
#  ...]

# %%
populate_query('sipsnap', get_search_config(client, 'baseline'))
# Out:
# {'query': {'multi_match': {'query': 'sipsnap',
#    'fields': ['id',
#     'title',
#     'category',
#     'bullets',
#     'description',
#     'attrs.Brand',
#     'attrs.Color']}},
#  'size': 10,
#  '_source': ['title', 'description', 'asin']}

# %%
for query in ubi_user_queries[:100]:
    for id,team in run_AB(client, query, 'baseline', 'baseline with title weight'):
        events = get_events(client, id, query)
        count = events['hits']['total']['value']
        if count:
            print(f"{team} {query}, {id} => {count}")
# Out:
# TeamB diamond band rings for women size 4, B07VRNXW2G => 121
# TeamB lidded ice cube trays, B08CDCBPSC => 112

# %%
for query in ubi_user_queries[:100]:
    for id,team in run_AB(client, query, 'baseline', 'baseline with title weight'):
        count = count_clicks(client, id, query)
        if count:
            print(f"{team} {query}, {id} => {count}")
# Out:
# TeamB lidded ice cube trays, B08CDCBPSC => 8

# %%
query_set_df = pd.DataFrame(ubi_user_queries, columns=['query'])
query_set_df
# Out:
#                                                   query
# 0     A long (mid calf length), lightweight beige/br...
# 1                                       iwo jima statue
# 2                   diamond band rings for women size 4
# 3                                            hair dryer
# 4             cursive kickoff handwriting without tears
# ...                                                 ...
# 9995                                     nope not today
# 9996   09 kia rio front bumper cover without fog lights
# 9997                       #6 fishing hook without barb
# 9998                     fortnight socks do not disturb
# 9999                         vintage suitcase for women
#
# [10000 rows x 1 columns]

# %%
query_set_df['res'] = query_set_df['query'].apply(lambda x: [ (id, count_clicks(client, id, x), team) for id,team in run_AB(client, x, 'baseline', 'baseline with title weight')])
query_set_df = query_set_df.explode('res')

# %%
query_set_df[['id', 'clicks', 'team']] = pd.DataFrame(query_set_df['res'].tolist(), index=query_set_df.index)
query_set_df
# Out:
#                                                   query  \
# 0     A long (mid calf length), lightweight beige/br...
# 0     A long (mid calf length), lightweight beige/br...
# 0     A long (mid calf length), lightweight beige/br...
# 0     A long (mid calf length), lightweight beige/br...
# 0     A long (mid calf length), lightweight beige/br...
# ...                                                 ...
# 9999                         vintage suitcase for women
# 9999                         vintage suitcase for women
# 9999                         vintage suitcase for women
# 9999                         vintage suitcase for women
# 9999                         vintage suitcase for women
#
#                          res          id  clicks   team
# 0     (B075WTPCQ5, 0, TeamA)  B075WTPCQ5     0.0  TeamA
# 0     (B071GRS2QR, 0, TeamB)  B071GRS2QR     0.0  TeamB
# 0     (B000A33JI2, 0, TeamA)  B000A33JI2     0.0  TeamA
# 0     (B077Y731X7, 0, TeamB)  B077Y731X7     0.0  TeamB
# 0     (B07XCPBM7Z, 0, TeamA)  B07XCPBM7Z     0.0  TeamA
# ...                      ...         ...     ...    ...
# 9999  (B07YRDYBNQ, 0, TeamB)  B07YRDYBNQ     0.0  TeamB
# 9999  (B01BV8D10U, 0, TeamA)  B01BV8D10U     0.0  TeamA
# 9999  (B071FVGCRW, 0, TeamB)  B071FVGCRW     0.0  TeamB
# 9999  (B07ZPNDHYN, 0, TeamA)  B07ZPNDHYN     0.0  TeamA
# 9999  (B0828NQSN7, 0, TeamA)  B0828NQSN7     0.0  TeamA
#
# [98016 rows x 5 columns]

# %%
query_set_df[query_set_df['team'] == 'TeamA'].describe()
# Out:
#              clicks
# count  46858.000000
# mean       0.024073
# std        0.575570
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       36.000000

# %%
query_set_df[query_set_df['team'] == 'TeamB'].describe()
# Out:
#              clicks
# count  51029.000000
# mean       0.028415
# std        0.570478
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       28.000000

# %%
query_set_df[query_set_df['team'] == 'TeamA'][query_set_df[query_set_df['team'] == 'TeamA']['clicks'] > 0]
# Out:
#                                        query                      res  \
# 112                     tiger stuffed animal   (B007JLUE4U, 9, TeamA)
# 194                         rug deep cleaner   (B07D46SQ63, 2, TeamA)
# 285                      gifts for godparent  (B07WMPLHD7, 11, TeamA)
# 357            fruitcakes with rum or brandy  (B00QKYOLAK, 12, TeamA)
# 405             best orbital polisher buffer  (B002654I46, 10, TeamA)
# ...                                      ...                      ...
# 9761                         try flex mirror   (B07QQZL14Q, 2, TeamA)
# 9763                     decora white switch   (B000U3DV2Q, 6, TeamA)
# 9793              silk bathing suit cover up   (B075M68XXX, 3, TeamA)
# 9876  marble composition notebook wide ruled   (B0034XS3I6, 6, TeamA)
# 9955                              tianbonsai   (B016OTEZ6A, 5, TeamA)
#
#               id  clicks   team
# 112   B007JLUE4U     9.0  TeamA
# 194   B07D46SQ63     2.0  TeamA
# 285   B07WMPLHD7    11.0  TeamA
# 357   B00QKYOLAK    12.0  TeamA
# 405   B002654I46    10.0  TeamA
# ...          ...     ...    ...
# 9761  B07QQZL14Q     2.0  TeamA
# 9763  B000U3DV2Q     6.0  TeamA
# 9793  B075M68XXX     3.0  TeamA
# 9876  B0034XS3I6     6.0  TeamA
# 9955  B016OTEZ6A     5.0  TeamA
#
# [171 rows x 5 columns]

# %%
query_set_df[query_set_df['team'] == 'TeamB'][query_set_df[query_set_df['team'] == 'TeamB']['clicks'] > 0]
# Out:
#                                                 query  \
# 64                              lidded ice cube trays
# 105                        mesh bag for washing shoes
# 159   l.o.l. surprise! winter disco cottage playhouse
# 449           black and white air max shoes for women
# 596                    corning ware lids french white
# ...                                               ...
# 9600                     navy blue bathroom towel set
# 9869                          gshock solar mens watch
# 9884                                    brakecrafters
# 9932                                 aqua full sheets
# 9980                   hudson baby receiving blankets
#
#                           res          id  clicks   team
# 64     (B08CDCBPSC, 8, TeamB)  B08CDCBPSC     8.0  TeamB
# 105    (B08PPDMQ8N, 8, TeamB)  B08PPDMQ8N     8.0  TeamB
# 159   (B085B26YB2, 19, TeamB)  B085B26YB2    19.0  TeamB
# 449   (B07HLHVPS6, 13, TeamB)  B07HLHVPS6    13.0  TeamB
# 596    (B00080XGNA, 6, TeamB)  B00080XGNA     6.0  TeamB
# ...                       ...         ...     ...    ...
# 9600   (B097Q3425Y, 7, TeamB)  B097Q3425Y     7.0  TeamB
# 9869  (B00791R1MI, 10, TeamB)  B00791R1MI    10.0  TeamB
# 9884   (B087KVRDKN, 1, TeamB)  B087KVRDKN     1.0  TeamB
# 9932  (B00VIWSZ6U, 10, TeamB)  B00VIWSZ6U    10.0  TeamB
# 9980   (B00X22T6GM, 9, TeamB)  B00X22T6GM     9.0  TeamB
#
# [187 rows x 5 columns]

# %%
query_set_df[query_set_df['team'] == 'TeamB'][query_set_df[query_set_df['team'] == 'TeamB']['clicks'] > 0].describe()
# Out:
#            clicks
# count  187.000000
# mean     7.754011
# std      5.390496
# min      1.000000
# 25%      4.000000
# 50%      7.000000
# 75%     10.000000
# max     28.000000

# %%
query_set_df[query_set_df['team'] == 'TeamA'][query_set_df[query_set_df['team'] == 'TeamA']['clicks'] > 0].describe()
# Out:
#            clicks
# count  171.000000
# mean     6.596491
# std      6.906586
# min      1.000000
# 25%      1.500000
# 50%      5.000000
# 75%      9.000000
# max     36.000000

# %%
query_set_df.to_csv('ubi_queries_df_3.csv')

# %%
get_search_config(client, name="baseline with title weight")
# Out:
# {'id': '40ae9a31-eaf0-40bd-b6fb-589979bd0604',
#  'name': 'baseline with title weight',
#  'timestamp': '2025-06-17T17:37:26.717Z',
#  'index': 'ecommerce',
#  'query': '{"query":{"multi_match":{"query":"%SearchText%","fields":["id","title^25","category","bullets","description","attrs.Brand","attrs.Color"]}}}',
#  'searchPipeline': ''}

# %%
get_search_config(client, name="baseline")
# Out:
# {'id': '78482772-d169-47dc-bb25-bb1a16a73c48',
#  'name': 'baseline',
#  'timestamp': '2025-06-17T17:37:26.557Z',
#  'index': 'ecommerce',
#  'query': '{"query":{"multi_match":{"query":"%SearchText%","fields":["id","title","category","bullets","description","attrs.Brand","attrs.Color"]}}}',
#  'searchPipeline': ''}
